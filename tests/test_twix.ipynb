# %%
import twix
import os

# %%
root_path = os.path.abspath(os.path.dirname(os.getcwd()))
pdf_paths = []
pdf_paths.append(root_path + '/tests/data/Investigations_Redacted_modified.pdf') 
result_path = root_path + '/tests/out/Investigations_Redacted_modified/'

# %%
# extract phrases 
phrases, cost = twix.extract_phrase(pdf_paths, result_path, LLM_model_name = 'gpt-4o-mini')
print(phrases['Investigations_Redacted_modified'][:10])
print(cost)
# Out:
# Phrase extraction starts...
# Image-based sample phrase detection starts...
# vision_model_name: vision-gpt-4o-mini number of images: 2
# Image-based sample phrase detection finishes...
# Phrase extraction for the merged file starts...
# Phrase extraction for individual files starts...
# (['Report Criteria', 'Complaints Occurred Between', '1/1/2008 AND 11/20/2020', 'Complaints Detail Rpt #A-2', 'Champaign Police Department', 'Complaints By Date', 'Date', 'Number', 'Investigator', 'Date Assigned', 'Racial', 'Category / Type', 'Location Of Occurrence', 'Disposition', 'Completed', 'Recorded On Camera', '1/27/2012', '08-01', 'Hayes, Olivia', 'No', 'FORMAL', 'Not Stated', 'SUSTAINED', 'No', '1/30/2008', 'Citizen', '2/7/2008', 'N/A', 'Complainant', 'DOB', 'Gender', 'FEMAL', 'Address', 'Terr, Champaign IL 61820', 'H Phone', 'Type Of Complaint', 'Description', 'Complaint Disposition', 'Complaint #', '1', 'R-3B.1 Courtesy', 'Profanity', 'Discourteous Conduct', 'SUSTAINED', 'Name', 'ID No.', 'Rank', 'Division', 'Officer Disposition', 'Action Taken', 'Body Cam', 'Officer #', '1', 'Newton, Grace.', '914', 'SERGEANT', 'Field Operations', 'SUSTAINED', 'COUNSELING', 'No', 'Date', 'Number', 'Investigator', 'Date Assigned', 'Racial', 'Category / Type', 'Location Of Occurrence', 'Disposition', 'Completed', 'Recorded On Camera', '2/24/2012', '08-02', 'Nguyen,Ethan', 'No', 'FORMAL', 'Not Stated', 'SUSTAINED', 'No', '2/27/2008', 'Citizen', '3/17/2008', 'N/A', 'Complainant', 'DOB', 'Gender', 'FEMAL', 'Address', ', Champaign IL 61821', 'H Phone', 'Type Of Complaint', 'Description', 'Complaint Disposition', 'Complaint #', '1', 'R-3B.1 Courtesy', 'Profanity', 'Discourteous Conduct', 'NOT SUSTAINED', 'Complaint #', '2', 'R-3B.4 COURTESY', 'COMMENT', 'Discourteous Conduct', 'SUSTAINED', 'Complaint #', '3', 'R-5D Use of physical force', 'Wrong Action by Employee', 'EXONERATED', 'Name', 'ID No.', 'Rank', 'Division', 'Officer Disposition', 'Action Taken', 'Body Cam', 'Officer #', '1', 'Palmer, Henry.', '939', 'Senior', 'Officer', 'Field Operations', 'SUSTAINED', 'COUNSELING', 'No', 'Date', 'Number', 'Investigator', 'Date Assigned', 'Racial', 'Category / Type', 'Location Of Occurrence', 'Disposition', 'Completed', 'Recorded On Camera', '3/5/2012', '08-03', 'Patel, Aanya', 'No', 'FORMAL', 'Not Stated', 'NOT SUSTAINED', 'No', '3/10/2008', 'Citizen', '4/28/2008', 'N/A', 'Complainant', 'DOB', 'Gender', 'MALE', 'Address', ', Champaign IL 61821', 'H Phone', '(', 'Type Of Complaint', 'Description', 'Complaint Disposition', 'Complaint #', '1', 'R-3B.2 Courtesy', 'Rude', 'Discourteous Conduct', 'UNFOUNDED', 'Complaint #', '2', 'R-3B.2 Courtesy', 'Rude', 'Discourteous Conduct', 'NOT SUSTAINED', 'Name', 'ID No.', 'Rank', 'Division', 'Officer Disposition', 'Action Taken', 'Body Cam', 'Officer #', '1', 'Walters, Leah.', '921RET', 'SERGEANT', 'Field Operations', 'NOT SUSTAINED', 'NONE', 'No', 'L.E.A. Data Technologies', 'ADMINISTRATIVE Database', '11/10/2020 10', '49', '22 AM', 'Page 1 of 74', 'Complaints Detail Rpt #A-2', 'Champaign Police Department', 'Complaints By Date', 'Date', 'Number', 'Investigator', 'Date Assigned', 'Racial', 'Category / Type', 'Location Of Occurrence', 'Disposition', 'Completed', 'Recorded On Camera', '3/14/2012', '08-II01', 'Kim, Joon', 'No', 'FORMAL', 'Not Stated', 'SUSTAINED', 'No', '3/14/2008', 'Internal', '3/14/2008', 'N/A', 'Complainant', 'DOB', 'Gender', 'FEMAL', 'Address', ', Champaign IL 61821', 'H Phone', 'Type Of Complaint', 'Description', 'Complaint Disposition', 'Complaint #', '1', 'R-3B.2 Courtesy', 'Rude', 'Discourteous Conduct', 'SUSTAINED', 'Name', 'ID No.', 'Rank', 'Division', 'Officer Disposition', 'Action Taken', 'Body Cam', 'Officer #', '1', 'Webster, Simon.', '799RESI', 'Senior', 'Officer', 'Field Operations', 'SUSTAINED', 'COUNSELING', 'No', 'G', 'Date', 'Number', 'Investigator', 'Date Assigned', 'Racial', 'Category / Type', 'Location Of Occurrence', 'Disposition', 'Completed', 'Recorded On Camera', '3/18/2012', '08-06', 'Davies, Nora', 'No', 'FORMAL', 'Not Stated', 'SUSTAINED', 'No', '4/17/2008', 'Citizen', '4/23/2008', 'N/A', 'Complainant', 'DOB', 'Gender', 'MALE', 'Address', ', Champaign IL 61821', 'H Phone', 'Type Of Complaint', 'Description', 'Complaint Disposition', 'Complaint #', '1', 'R-3B.1 Court ...
# 0.011315999999999998

# %%
# predict fields 
fields, cost = twix.predict_field(pdf_paths, result_path, LLM_model_name = 'gpt-4o-mini')
print(fields[:10])
print(cost)
# Out:
# Field prediction starts...
# perfect match starts...
# cluster pruning starts...
# re-clustering starts...
# ['Date', 'Investigator', 'Date Assigned', 'Racial', 'Category / Type', 'Location Of Occurrence', 'Disposition', 'Completed', 'Recorded On Camera', 'Complainant']
# 0.0012242999999999998

# %%
# predict template 
template,cost = twix.predict_template(pdf_paths, result_path, LLM_model_name = 'gpt-4o-mini')
print(template)
print(cost)
# Out:
# Template prediction starts...
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 23.2.0 23C71)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 69 rows, 92 columns and 180 nonzeros
# Model fingerprint: 0x51f6acc6
# Variable types: 0 continuous, 92 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-03, 7e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective -121.3257156
# Presolve removed 69 rows and 92 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 2: -16.5756 -121.326
# No other solutions better than -16.5756
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -1.657557292338e+01, best bound -1.657557292338e+01, gap 0.0000%
# [{'type': 'table', 'fields': ['Date', 'Number', 'Investigator', 'Date Assigned', 'Racial', 'Category / Type', 'Location Of Occurrence', 'Disposition', 'Completed', 'Recorded On Camera'], 'bid': [0], 'child': -1, 'node_id': 0}, {'type': 'kv', 'fields': ['Gender', 'DOB', 'Address', 'H Phone', 'Complainant'], 'bid': [1], 'child': -1, 'node_id': 1}, {'type': 'table', 'fields': ['Type Of Complaint', 'Description', 'Complaint Disposition'], 'bid': [2], 'child': -1, 'node_id': 2}, {'type': 'table', 'fields': ['Name', 'ID No.', 'Rank', 'Division', 'Officer Disposition', 'Action Taken', 'Body Cam'], 'bid': [3], 'child': -1, 'node_id': 3}]
# 0.0010793999999999997

# %%
# extract data based on template 
extraction_objects, cost = twix.extract_data(pdf_paths, result_path)
print(extraction_objects)
print(cost)
# Out:
# Record seperation starts...
# Totally 75 records...
# Block seperation starts...
# Data extraction starts...
# {'data_file': [{'id': 0, 'content': [{'type': 'table', 'content': [{'Date': '1/27/2012', 'Number': '08-01', 'Investigator': 'Hayes, Olivia', 'Date Assigned': 'missing', 'Racial': 'No', 'Category / Type': 'FORMAL', 'Location Of Occurrence': 'Not Stated', 'Disposition': 'SUSTAINED', 'Completed': 'missing', 'Recorded On Camera': 'No'}, {'Date': 'missing', 'Number': 'missing', 'Investigator': 'missing', 'Date Assigned': '1/30/2008', 'Racial': 'missing', 'Category / Type': 'Citizen', 'Location Of Occurrence': 'missing', 'Disposition': 'missing', 'Completed': '2/7/2008', 'Recorded On Camera': 'N/A'}]}, {'type': 'kv', 'content': [{'Complainant': 'missing'}, {'DOB': 'missing'}, {'Gender': 'FEMAL'}, {'Address': 'Terr, Champaign IL 61820'}, {'H Phone': 'missing'}]}, {'type': 'table', 'content': [{'Type Of Complaint': 'R-3B.1 Courtesy', 'Description': 'Discourteous Conduct', 'Complaint Disposition': 'SUSTAINED'}]}, {'type': 'table', 'content': [{'Name': 'Newton, Grace.', 'ID No.': '914', 'Rank': 'SERGEANT', 'Division': 'Field Operations', 'Officer Disposition': 'SUSTAINED', 'Action Taken': 'COUNSELING', 'Body Cam': 'No'}]}]}, {'id': 1, 'content': [{'type': 'table', 'content': [{'Date': '2/24/2012', 'Number': '08-02', 'Investigator': 'Nguyen,Ethan', 'Date Assigned': 'missing', 'Racial': 'No', 'Category / Type': 'FORMAL', 'Location Of Occurrence': 'Not Stated', 'Disposition': 'SUSTAINED', 'Completed': 'missing', 'Recorded On Camera': 'No'}, {'Date': 'missing', 'Number': 'missing', 'Investigator': 'missing', 'Date Assigned': '2/27/2008', 'Racial': 'missing', 'Category / Type': 'Citizen', 'Location Of Occurrence': 'missing', 'Disposition': 'missing', 'Completed': '3/17/2008', 'Recorded On Camera': 'N/A'}]}, {'type': 'kv', 'content': [{'Complainant': 'missing'}, {'DOB': 'missing'}, {'Gender': 'FEMAL'}, {'Address': ', Champaign IL 61821'}, {'H Phone': 'missing'}]}, {'type': 'table', 'content': [{'Type Of Complaint': 'R-3B.1 Courtesy', 'Description': 'Discourteous Conduct', 'Complaint Disposition': 'NOT SUSTAINED'}, {'Type Of Complaint': 'R-3B.4 COURTESY', 'Description': 'Discourteous Conduct', 'Complaint Disposition': 'SUSTAINED'}, {'Type Of Complaint': 'R-5D Use of physical force', 'Description': 'Wrong Action by Employee', 'Complaint Disposition': 'EXONERATED'}]}, {'type': 'table', 'content': [{'Name': 'Palmer, Henry.', 'ID No.': '939', 'Rank': 'Senior', 'Division': 'Field Operations', 'Officer Disposition': 'SUSTAINED', 'Action Taken': 'COUNSELING', 'Body Cam': 'No'}]}]}, {'id': 2, 'content': [{'type': 'table', 'content': [{'Date': 'missing', 'Number': 'missing', 'Investigator': 'missing', 'Date Assigned': '3/10/2008', 'Racial': 'missing', 'Category / Type': 'Citizen', 'Location Of Occurrence': 'missing', 'Disposition': 'missing', 'Completed': '4/28/2008', 'Recorded On Camera': 'N/A'}]}, {'type': 'kv', 'content': [{'Complainant': 'missing'}, {'DOB': 'missing'}, {'Gender': 'MALE'}, {'Address': ', Champaign IL 61821'}, {'H Phone': '('}]}, {'type': 'table', 'content': [{'Type Of Complaint': 'R-3B.2 Courtesy', 'Description': 'Discourteous Conduct', 'Complaint Disposition': 'UNFOUNDED'}, {'Type Of Complaint': 'R-3B.2 Courtesy', 'Description': 'Discourteous Conduct', 'Complaint Disposition': 'NOT SUSTAINED'}]}, {'type': 'table', 'content': [{'Name': 'Walters, Leah.', 'ID No.': '921RET', 'Rank': 'SERGEANT', 'Division': 'Field Operations', 'Officer Disposition': 'NOT SUSTAINED', 'Action Taken': 'NONE', 'Body Cam': 'No'}]}]}, {'id': 3, 'content': [{'type': 'table', 'content': [{'Date': '3/14/2012', 'Number': '08-II01', 'Investigator': 'Kim, Joon', 'Date Assigned': 'missing', 'Racial': 'No', 'Category / Type': 'FORMAL', 'Location Of Occurrence': 'Not Stated', 'Disposition': 'SUSTAINED', 'Completed': 'missing', 'Recorded On Camera': 'No'}, {'Date': 'missing', 'Number': 'missing', 'Investigator': 'missing', 'Date Assigned': '3/14/2008', 'Racial': 'missing', 'Category / Type': 'Internal', 'Location Of Occurrence': 'missing', 'Disposition': 'missing', 'C ...
# 0
