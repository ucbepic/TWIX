# %%
import twix
import os

# %%
root_path = os.path.abspath(os.path.dirname(os.getcwd()))
pdf_paths = []
pdf_paths.append(root_path + '/tests/data/Investigations_Redacted_original.pdf')

# %%
# extract phrases 

phrases = twix.extract_phrase(pdf_paths)
phrases['merged_data_files'][:10]
# Out:
# Phrase extraction starts...
# Processing  /Users/yiminglin/Documents/Codebase/Pdf_reverse/tests/out/Investigations_Redacted_original/merged.pdf
# Word extraction starts...
# Criteria Complaints
# Between 1/1/2008
# Complainant DOB
# DOB Gender
# Gender FEMAL
# Address Terr,
# Phone Type
# # 1
# Courtesy Profanity
# # 1
# Complainant DOB
# DOB Gender
# Gender FEMAL
# Address ,
# Phone Type
# # 1
# Courtesy Profanity
# # 2
# COURTESY COMMENT
# # 3
# # 1
# Complainant DOB
# DOB Gender
# Gender MALE
# Address ,
# Phone (
# # 1
# Courtesy Rude
# # 2
# Courtesy Rude
# # 1
# 10 49
# 49 22
# Complainant DOB
# DOB Gender
# Gender FEMAL
# Address ,
# Phone Type
# # 1
# Courtesy Rude
# # 1
# Complainant DOB
# DOB Gender
# Gender MALE
# Address ,
# Phone Type
# # 1
# Courtesy Profanity
# # 2
# COURTESY COMMENT
# # 1
# Complainant DOB
# DOB Gender
# Gender MALE
# Address Ct,
# Phone (
# # 1
# # 1
# # 2
# Complainant DOB
# DOB Gender
# Gender FEMAL
# Address ,
# Phone Type
# # 1
# # 1
# 10 49
# 49 22
# Complainant DOB
# DOB Gender
# Gender FEMAL
# Address ,
# Phone Type
# # 1
# # 1
# Complainant DOB
# DOB Gender
# Gender FEMAL
# Address ,
# Phone Type
# # 1
# # 1
# Complainant CPD
# DOB Gender
# Gender Address
# Address NOT
# Phone Type
# # 1
# # 1
# Complainant DOB
# DOB Gender
# Gender FEMAL
# Address ,
# Phone Type
# # 1
# # 1
# 10 49
# 49 22
# Complainant DOB
# DOB Gender
# Gender FEMAL
# Address ,
# Phone Type
# # 1
# # 1
# Complainant DOB
# DOB Gender
# Gender MALE
# Address ,
# Phone Type
# # 1
# COURTESY COMMENT
# # 2
# # 1
# Complainant DOB
# DOB Gender
# Gender FEMAL
# Address Champaign
# Phone Type
# # 1
# # 1
# Complainant DOB
# DOB Gender
# Gender MALE
# Address ,
# Phone Type
# # 1
# # 2
# # 1
# # 2
# 10 49
# 49 22
# Complainant DOB
# DOB Gender
# Gender MALE
# Address ,
# Phone Type
# # 1
# # 1
# Complainant DOB
# DOB Gender
# Gender FEMAL
# Address ,
# Phone Type
# # 1
# # 1
# Complainant DOB
# DOB Gender
# Gender FEMAL
# Address ,
# Phone (
# # 1
# # 2
# # 1
# # 2
# Complainant DOB
# DOB Gender
# Gender MALE
# Address ,
# Phone (
# # 1
# Courtesy Rude
# # 2
# # 1
# 10 49
# 49 22
# Learn rules for word concatation...
# Refine phases extraction based on learned rules...
# Processing  /Users/yiminglin/Documents/Codebase/Pdf_reverse/tests/data/Investigations_Redacted_original.pdf
# Word extraction starts...
# Criteria Complaints
# Between 1/1/2008
# Complainant DOB
# DOB Gender
# Gender FEMAL
# Address Terr,
# Phone Type
# # 1
# Courtesy Profanity
# # 1
# Complainant DOB
# DOB Gender
# Gender FEMAL
# Address ,
# Phone Type
# # 1
# Courtesy Profanity
# # 2
# COURTESY COMMENT
# # 3
# # 1
# Complainant DOB
# DOB Gender
# Gender MALE
# Address ,
# Phone (
# # 1
# Courtesy Rude
# # 2
# Courtesy Rude
# # 1
# 10 49
# 49 22
# Complainant DOB
# DOB Gender
# Gender FEMAL
# Address ,
# Phone Type
# # 1
# Courtesy Rude
# # 1
# Complainant DOB
# DOB Gender
# Gender MALE
# Address ,
# Phone Type
# # 1
# Courtesy Profanity
# # 2
# COURTESY COMMENT
# # 1
# Complainant DOB
# DOB Gender
# Gender MALE
# Address Ct,
# Phone (
# # 1
# # 1
# # 2
# Complainant DOB
# DOB Gender
# Gender FEMAL
# Address ,
# Phone Type
# # 1
# # 1
# 10 49
# 49 22
# Complainant DOB
# DOB Gender
# Gender FEMAL
# Address ,
# Phone Type
# # 1
# # 1
# Complainant DOB
# DOB Gender
# Gender FEMAL
# Address ,
# Phone Type
# # 1
# # 1
# Complainant CPD
# DOB Gender
# Gender Address
# Address NOT
# Phone Type
# # 1
# # 1
# Complainant DOB
# DOB Gender
# Gender FEMAL
# Address ,
# Phone Type
# # 1
# # 1
# 10 49
# 49 22
# Complainant DOB
# DOB Gender
# Gender FEMAL
# Address ,
# Phone Type
# # 1
# # 1
# Complainant DOB
# DOB Gender
# Gender MALE
# Address ,
# Phone Type
# # 1
# COURTESY COMMENT
# # 2
# # 1
# Complainant DOB
# DOB Gender
# Gender FEMAL
# Address Champaign
# Phone Type
# # 1
# # 1
# Complainant DOB
# DOB Gender
# Gender MALE
# Address ,
# Phone Type
# # 1
# # 2
# # 1
# # 2
# 10 49
# 49 22
# Complainant DOB
# DOB Gender
# Gender MALE
# Address ,
# Phone Type
# # 1
# # 1
# Complainant DOB
# DOB Gender
# Gender FEMAL
# Address ,
# Phone Type
# # 1
# # 1
# Complainant DOB
# DOB Gender
# Gender FEMAL
# Address ,
# Phone (
# # 1
# # 2
# # 1
# # 2
# Complainant DOB
# DOB Gender
# Gender MALE
# Address ,
# Phone (
# # 1
# Courtesy Rude
# # 2
# # 1
# 10 49
# 49 22
# Complainant DOB
# DOB Gender
# Gender MALE
# Address ,
# Phone Type
# # 1
# Courtesy Conduct
# # 1
# Complainant DOB
# DOB Gender
# Gender MALE
# Address ,
# Phone Type
# # 1
# # 2
# # 3
# # 4
# # 1
# Complainant DOB
# DOB Gender
# Gender MALE
# Address ,
# Phone Type
# # 1
# # 2
# # 3
# # 4
# # 1
# 10 49
# 49 22
# Complainant NOT
# DOB Gender
# Gender Address
# Address NOT
# Phone Type
# # 1
# # 1
# Complainant DOB
# DOB Gender
# Gender MALE
# Address Champaign
# Phone Type
# # 1
# # 2
# # 1
# Complainant DOB
# DOB Gender
# Gender MALE
# Address Central
# Phone Type
# # 1
# # 1
# 10 49
# 49 22
# Complainant DOB
# DOB Gender
# Gender FEMAL
# Address ,
# Phone Type
# # 1
# # 2
# # 3
# # 1
# # 2
# Complainant DOB
# DOB Gender
# Gender MALE
# Address 1302
# Phone Type
# # 1
# # 1
# Complainant DOB
# DOB Gender
# Gender MALE
# Address ,
# Phone Type
# # 1
# # 1
# Complainant NOT
# DOB Gender
# Gender Address
# Address NOT
# Phone Type
# # 1
# # 1
# 10 49
# 49 22
# Complainant NOT
# DOB Gender
# Gender Address
# Address NOT
# Phone Type
# # 1
# # 1
# Complainant DOB
# DOB Gender
# Gender FEMAL
# Address ,
# Phone Type
# # 1
# Courtesy Rude
# # 2
# # 1
# Complainant CPD
# DOB Gender
# Gender Address
# Address NOT
# Phone Type
# # 1
# # 2
# # 3
# # 4
# # 1
# 10 49
# 49 22
# Complainant DOB
# DOB Gender
# Gender FEMAL
# Address 1001
# Phone Type
# # 1
# # 2
# Courtesy Rude
# # 1
# Complainant DOB
# DOB Gender
# Gender MALE
# Address 609
# Phone Type
# # 1
# # 1
# # 2
# Complainant DOB
# DOB Gender
# Gender FEMAL
# Address 210.5
# Phone (
# # 1
# # 1
# Complainant Internal
# DOB Gender
# Gender Address
# Address NOT
# Phone Type
# # 1
# # 1
# 10 49
# 49 22
# Complainant DOB
# DOB Gender
# Gender MALE
# Address Urbana
# Phone Type
# # 1
# Courtesy Conduct
# # 1
# Complainant DOB
# DOB Gender
# Gender MALE
# Address IL
# Phone Type
# # 1
# Courtesy Profanity
# # 2
# # 1
# Complainant DOB
# DOB Gender
# Gender FEMAL
# Address ,
# Phone Type
# # 1
# # 2
# # 1
# Complainant DOB
# DOB Gender
# Gender FEMAL
# Address Champaign
# Phone (
# # 1
# # 1
# 10 49
# 49 22
# Complainant DOB
# DOB Gender
# Gender MALE
# Address Urbana
# Phone Type
# # 1
# # 2
# # 1
# Complainant DOB
# DOB Gender
# Gender MALE
# Address ,
# Phone Type
# # 1
# # 2
# # 1
# # 2
# Complainant DOB
# DOB Gender
# Gender MALE
# Address HOMELESS,
# Phone Type
# # 1
# # 2
# # 1
# 10 49
# 49 23
# Complainant DOB
# DOB Gender
# Gender FEMAL
# Address ,
# Phone Type
# # 1
# Courtesy Rude
# # 2
# # 1
# Complainant DOB
# DOB Gender
# Gender MALE
# Address STATEVILLE
# Phone Type
# # 1
# Courtesy Rude
# # 2
# # 1
# Complainant DOB
# DOB Gender
# Gender FEMAL
# Address GURNEE
# Phone Type
# # 1
# # 2
# # 1
# Complainant DOB
# DOB Gender
# Gender MALE
# Address IL
# Phone (
# # 1
# # 2
# # 1
# 10 49
# 49 23
# Complainant NOT
# DOB Gender
# Gender Address
# Address NOT
# Phone Type
# # 1
# # 1
# Complainant INTERNAL
# DOB Gender
# Gender Address
# Address NOT
# Phone Type
# # 1
# # 1
# Complainant DOB
# DOB Gender
# Gender FEMAL
# Address IL
# Phone Type
# # 1
# Courtesy Rude
# # 1
# Complainant DOB
# DOB Gender
# Gender FEMAL
# Address Champaign
# Phone Type
# # 1
# Courtesy Profanity
# # 2
# # 1
# # 2
# 10 49
# 49 23
# Complainant DOB
# DOB Gender
# Gender MALE
# Address ,
# Phone Type
# # 1
# # 2
# # 1
# # 2
# Complainant DOB
# DOB Gender
# Gender MALE
# Address ,
# Phone (
# # 1
# Courtesy Conduct
# # 1
# Complainant DOB
# DOB Gender
# Gender MALE
# Address ,
# Phone (
# # 1
# Courtesy Rude
# # 2
# # 1
# Complainant DOB
# DOB Gender
# Gender MALE
# Address Urbana
# Phone (
# # 1
# # 2
# # 1
# 10 49
# 49 23
# Complainant DOB
# DOB Gender
# Gender FEMAL
# Address Champaign
# Phone (
# # 1
# Courtesy Rude
# # 2
# # 1
# # 2
# Complainant DOB
# DOB Gender
# Gender MALE
# Address STATESVILLE
# Phone Type
# # 1
# # 1
# Complainant DEPARTMENT
# DOB Gender
# Gender Address
# Address Not
# Phone Type
# # 1
# # 1
# Complainant DOB
# DOB Gender
# Gender MALE
# Address IL
# Phone (
# # 1
# COURTESY COMMENT
# # 2
# # 3
# # 1
# 10 49
# 49 23
# Complainant DOB
# DOB Gender
# Gender FEMAL
# Address ,
# Phone (
# # 1
# # 1
# Complainant DOB
# DOB Gender
# Gender FEMAL
# Address Champaign
# Phone (
# # 1
# # 2
# COMMUNICATION TRUTHFULNESS
# # 1
# Complainant DOB
# DOB Gender
# Gender FEMAL
# Address ,
# Phone Type
# # 1
# # 2
# # 3
# # 1
# Complainant Department
# DOB Gender
# Gender Address
# Address Not
# Phone Type
# # 1
# # 1
# 10 49
# 49 23
# Complainant DOB
# DOB Gender
# Gender MALE
# Address IL
# Phone (
# # 1
# # 1
# Complainant DOB
# DOB Gender
# Gender FEMAL
# Address IL
# Phone Type
# # 1
# Courtesy Profanity
# # 2
# # 1
# Complainant DOB
# DOB Gender
# Gender MALE
# Address ,
# Phone Type
# # 1
# # 1
# Complainant DOB
# DOB Gender
# Gender FEMAL
# Address IL
# Phone Type
# # 1
# Courtesy Rude
# # 1
# 10 49
# 49 23
# Complainant DOB
# DOB Gender
# Gender FEMAL
# Address Champaign
# Phone (
# # 1
# # 1
# Complainant DOB
# DOB Gender
# Gender MALE
# Address Champaign
# Phone (
# # 1
# Courtesy Profanity
# # 2
# # 3
# # 1
# # 2
# Complainant DOB
# DOB Gender
# Gender FEMAL
# Address Champaign
# Phone (
# # 1
# # 1
# Complainant DOB
# DOB Gender
# Gender MALE
# Address Champaign
# Phone Type
# # 1
# # 1
# 10 49
# 49 23
# Complainant DOB
# DOB Gender
# Gender MALE
# Address Champaign
# Phone (
# # 1
# # 1
# Complainant DOB
# DOB Gender
# Gender FEMAL
# Address Champaign
# Phone Type
# # 1
# # 1
# Complainant DOB
# DOB Gender
# Gender FEMAL
# Address ,
# Phone Type
# # 1
# COMMUNICATION TRUTHFULNESS
# # 2
# # 3
# # 1
# Complainant DOB
# DOB Gender
# Gender FEMAL
# Address Drive,
# Phone Type
# # 1
# # 2
# # 1
# 10 49
# 49 27
# Learn rules for word concatation...
# Refine phases extraction based on learned rules...
# (['Report Criteria',
#   'Complaints Occurred Between',
#   '1/1/2008 AND 11/20/2020',
#   'Complaints Detail Rpt #A-2',
#   'Champaign Police Department',
#   'Complaints By Date',
#   'Date',
#   'Number',
#   'Investigator',
#   'Date Assigned',
#   'Racial',
#   'Category / Type',
#   'Location Of Occurrence',
#   'Disposition',
#   'Completed',
#   'Recorded On Camera',
#   '1/27/2008',
#   '08-01',
#   'Swenson, Jon',
#   'No',
#   'FORMAL',
#   'Not Stated',
#   'SUSTAINED',
#   'No',
#   '1/30/2008',
#   'Citizen',
#   '2/7/2008',
#   'N/A',
#   'Complainant',
#   'DOB',
#   'Gender',
#   'FEMAL',
#   'Address',
#   'Terr, Champaign IL 61820',
#   'H Phone',
#   'Type Of Complaint',
#   'Description',
#   'Complaint Disposition',
#   'Complaint #',
#   '1',
#   'R-3B.1 Courtesy',
#   'Profanity',
#   'Discourteous Conduct',
#   'SUSTAINED',
#   'Name',
#   'ID No.',
#   'Rank',
#   'Division',
#   'Officer Disposition',
#   'Action Taken',
#   'Body Cam',
#   'Officer #',
#   '1',
#   'Griffet, David I.',
#   '914',
#   'SERGEANT',
#   'Field Operations',
#   'SUSTAINED',
#   'COUNSELING',
#   'No',
#   'Date',
#   'Number',
#   'Investigator',
#   'Date Assigned',
#   'Racial',
#   'Category / Type',
#   'Location Of Occurrence',
#   'Disposition',
#   'Completed',
#   'Recorded On Camera',
#   '2/24/2008',
#   '08-02',
#   'Swan, Scott',
#   'No',
#   'FORMAL',
#   'Not Stated',
#   'SUSTAINED',
#   'No',
#   '2/27/2008',
#   'Citizen',
#   '3/17/2008',
#   'N/A',
#   'Complainant',
#   'DOB',
#   'Gender',
#   'FEMAL',
#   'Address',
#   ', Champaign IL 61821',
#   'H Phone',
#   'Type Of Complaint',
#   'Description',
#   'Complaint Disposition',
#   'Complaint #',
#   '1',
#   'R-3B.1 Courtesy',
#   'Profanity',
#   'Discourteous Conduct',
#   'NOT SUSTAINED',
#   'Complaint #',
#   '2',
#   'R-3B.4 COURTESY',
#   'COMMENT',
#   'Discourteous Conduct',
#   'SUSTAINED',
#   'Complaint #',
#   '3',
#   'R-5D Use of physical force',
#   'Wrong Action by Employee',
#   'EXONERATED',
#   'Name',
#   'ID No.',
#   'Rank',
#   'Division',
#   'Officer Disposition',
#   'Action Taken',
#   'Body Cam',
#   'Officer #',
#   '1',
#   'Petrilli, Thomas P.',
#   '939',
#   'Senior',
#   'Officer',
#   'Field Operations',
#   'SUSTAINED',
#   'COUNSELING',
#   'No',
#   'Date',
#   'Number',
#   'Investigator',
#   'Date Assigned',
#   'Racial',
#   'Category / Type',
#   'Location Of Occurrence',
#   'Disposition',
#   'Completed',
#   'Recorded On Camera',
#   '3/5/2008',
#   '08-03',
#   'Paulus, Michael',
#   'No',
#   'FORMAL',
#   'Not Stated',
#   'NOT SUSTAINED',
#   'No',
#   '3/10/2008',
#   'Citizen',
#   '4/28/2008',
#   'N/A',
#   'Complainant',
#   'DOB',
#   'Gender',
#   'MALE',
#   'Address',
#   ', Champaign IL 61821',
#   'H Phone',
#   '(',
#   'Type Of Complaint',
#   'Description',
#   'Complaint Disposition',
#   'Complaint #',
#   '1',
#   'R-3B.2 Courtesy',
#   'Rude',
#   'Discourteous Conduct',
#   'UNFOUNDED',
#   'Complaint #',
#   '2',
#   'R-3B.2 Courtesy',
#   'Rude',
#   'Discourteous Conduct',
#   'NOT SUSTAINED',
#   'Name',
#   'ID No.',
#   'Rank',
#   'Division',
#   'Officer Disposition',
#   'Action Taken',
#   'Body Cam',
#   'Officer #',
#   '1',
#   'Shepard, Charles F.',
#   '921RET',
#   'SERGEANT',
#   'Field Operations',
#   'NOT SUSTAINED',
#   'NONE',
#   'No',
#   'L.E.A. Data Technologies',
#   'ADMINISTRATIVE Database',
#   '11/10/2020 10',
#   '49',
#   '22 AM',
#   'Page 1 of 74',
#   'Complaints Detail Rpt #A-2',
#   'Champaign Police Department',
#   'Complaints By Date',
#   'Date',
#   'Number',
#   'Investigator',
#   'Date Assigned',
#   'Racial',
#   'Category / Type',
#   'Location Of Occurrence',
#   'Disposition',
#   'Completed',
#   'Recorded On Camera',
#   '3/14/2008',
#   '08-II01',
#   'Swan, Scott',
#   'No',
#   'FORMAL',
#   'Not Stated',
#   'SUSTAINED',
#   'No',
#   '3/14/2008',
#   'Internal',
#   '3/14/2008',
#   'N/A',
#   'Complainant',
#   'DOB',
#   'Gender',
#   'FEMAL',
#   'Address',
#   ', Champaign IL 61821',
#   'H Phone',
#   'Type Of Complaint',
#   'Description',
#   'Complaint Disposition',
#   'Complaint #',
#   '1',
#   'R-3B.2 Courtesy',
#   'Rude',
#   'Discourteous Conduct',
#   'SUSTAINED',
#   'Name',
#   'ID No.',
#   'Rank',
#   'Division',
#   'Officer Disposition',
#   'Action Taken',
#   'Body Cam',
#   'Officer #',
#   '1',
#   'Wilberg, Richard W.',
#   '799RESI',
#   'Senior',
#   'Officer',
#   'Field Operations',
#   'SUSTAINED',
#   'COUNSELING',
#   'No',
#   'G',
#   'Date',
#   'Number',
#   'Investigator',
#   'Date Assigned',
#   'Racial',
#   'Category / Type',
#   'Location Of Occurrence',
#   'Disposition',
#   'Completed',
#   'Recorded On Camera',
#   '3/18/2008',
#   '08-06',
#   'Gallo, Joe',
#   'No',
#   'FORMAL',
#   'Not Stated',
#   'SUSTAINED',
#   'No',
#   '4/17/2008',
#   'Citizen',
#   '4/23/2008',
#   'N/A',
#   'Complainant',
#   'DOB',
#   'Gender',
#   'MALE',
#   'Address',
#   ', Champaign IL 61821',
#   'H Phone',
#   'Type Of Complaint',
#   'Description',
#   'Complaint Disposition',
#   'Complaint #',
#   '1',
#   'R-3B.1 Courtesy',
#   'Profanity',
#   'Discourteous Conduct',
#   'NOT SUSTAINED',
#   'Complaint #',
#   '2',
#   'R-3B.4 COURTESY',
#   'COMMENT',
#   'Discourteous Conduct',
#   'SUSTAINED',
#   'Name',
#   'ID No.',
#   'Rank',
#   'Division',
#   'Officer Disposition',
#   'Action Taken',
#   'Body Cam',
#   'Officer #',
#   '1',
#   'Kelly, Patrick M.',
#   '722-Ret',
#   'DETECTIVE',
#   'Operations Supp',
#   'SUSTAINED',
#   'COUNSELING',
#   'No',
#   'Date',
#   'Number',
#   'Investigator',
#   'Date Assigned',
#   'Racial',
#   'Category / Type',
#   'Location Of Occurrence',
#   'Disposition',
#   'Completed',
#   'Recorded On Camera',
#   '3/22/2008',
#   '08-04a',
#   'Swenson, Jon',
#   'No',
#   'FORMAL',
#   'Not Stated',
#   'UNFOUNDED',
#   'No',
#   '4/16/2008',
#   'Citizen',
#   '5/1/2008',
#   'N/A',
#   'Complainant',
#   'DOB',
#   'Gender',
#   'MALE',
#   'Address',
#   'Ct, Rantoul IL 61866',
#   'H Phone',
#   '(',
#   'Type Of Complaint',
#   'Description',
#   'Complaint Disposition',
#   'Complaint #',
#   '1',
#   'R-5D Use of physical force',
#   'Wrong Action by Employee',
#   'UNFOUNDED',
#   'Name',
#   'ID No.',
#   'Rank',
#   'Division',
#   'Officer Disposition',
#   'Action Taken',
#   'Body Cam',
#   'Officer #',
#   '1',
#   'Lack, Aaron V.',
#   '920',
#   'SERGEANT',
#   'Field Operations',
#   'UNFOUNDED',
#   'NONE',
#   'No',
#   'Officer #',
#   '2',
#   'MULTIPLE OFFICERS/EMPLOY',
#   'NOT STATED',
#   'NOT ENTERED',
#   'UNFOUNDED',
#   'NONE',
#   'No',
#   'Date',
#   'Number',
#   'Investigator',
#   'Date Assigned',
#   'Racial',
#   'Category / Type',
#   'Location Of Occurrence',
#   'Disposition',
#   'Completed',
#   'Recorded On Camera',
#   '3/22/2008',
#   '08-04b',
#   'Swenson, Jon',
#   'No',
#   'FORMAL',
#   'Not Stated',
#   'UNFOUNDED',
#   'No',
#   '4/16/2008',
#   'Citizen',
#   '5/1/2008',
#   'N/A',
#   'Complainant',
#   'DOB',
#   'Gender',
#   'FEMAL',
#   'Address',
#   ', CHICAGO IL 60644-2803',
#   'H Phone',
#   'Type Of Complaint',
#   'Description',
#   'Complaint Disposition',
#   'Complaint #',
#   '1',
#   'R-5D Use of physical force',
#   'Wrong Action by Employee',
#   'UNFOUNDED',
#   'Name',
#   'ID No.',
#   'Rank',
#   'Division',
#   'Officer Disposition',
#   'Action Taken',
#   'Body Cam',
#   'Officer #',
#   '1',
#   'MULTIPLE OFFICERS/EMPLOY',
#   'NOT STATED',
#   'NOT ENTERED',
#   'UNFOUNDED',
#   'NONE',
#   'No',
#   'L.E.A. Data Technologies',
#   'ADMINISTRATIVE Database',
#   '11/10/2020 10',
#   '49',
#   '22 AM',
#   'Page 2 of 74',
#   'Complaints Detail Rpt #A-2',
#   'Champaign Police Department',
#   'Complaints By Date',
#   'Date',
#   'Number',
#   'Investigator',
#   'Date Assigned',
#   'Racial',
#   'Category / Type',
#   'Location Of Occurrence',
#   'Disposition',
#   'Completed',
#   'Recorded On Camera',
#   '3/22/2008',
#   '08-04c',
#   'Swenson, Jon',
#   'No',
#   'FORMAL',
#   'Not Stated',
#   'EXONERATED',
#   'No',
#   '4/16/2008',
#   'Citizen',
#   '5/1/2008',
#   'N/A',
#   'Complainant',
#   'DOB',
#   'Gender',
#   'FEMAL',
#   'Address',
#   ', Champaign IL 61820',
#   'H Phone',
#   'Type Of Complaint',
#   'Description',
#   'Complaint Disposition',
#   'Complaint #',
#   '1',
#   'R-5D Use of physical force',
#   'Wrong Action by Employee',
#   'EXONERATED',
#   'Name',
#   'ID No.',
#   'Rank',
#   'Division',
#   'Officer Disposition',
#   'Action Taken',
#   'Body Cam',
#   'Officer #',
#   '1',
#   'MULTIPLE OFFICERS/EMPLOY',
#   'NOT STATED',
#   'NOT ENTERED',
#   'UNFOUNDED',
#   'NONE',
#   'No',
#   'Date',
#   'Number',
#   'Investigator',
#   'Date Assigned',
#   'Racial',
#   'Category / Type',
#   'Location Of Occurrence',
#   'Disposition',
#   'Completed',
#   'Recorded On Camera',
#   '3/22/2008',
#   '08-04d',
#   'Swenson, Jon',
#   'No',
#   'FORMAL',
#   'Not Stated',
#   'EXONERATED',
#   'No',
#   '4/16/2008',
#   'Citizen',
#   '5/1/2008',
#   'N/A',
#   'Complainant',
#   'DOB',
#   'Gender',
#   'FEMAL',
#   'Address',
#   ', Rantoul IL 61866',
#   'H Phone',
#   'Type Of Complaint',
#   'Description',
#   'Complaint Disposition',
#   'Complaint #',
#   '1',
#   'R-5D Use of physical force',
#   'Wrong Action by Employee',
#   'EXONERATED',
#   'Name',
#   'ID No.',
#   'Rank',
#   'Division',
#   'Officer Disposition',
#   'Action Taken',
#   'Body Cam',
#   'Officer #',
#   '1',
#   'MULTIPLE OFFICERS/EMPLOY',
#   'NOT STATED',
#   'NOT ENTERED',
#   'UNFOUNDED',
#   'NONE',
#   'No',
#   'Date',
#   'Number',
#   'Investigator',
#   'Date Assigned',
#   'Racial',
#   'Category / Type',
#   'Location Of Occurrence',
#   'Disposition',
#   'Completed',
#   'Recorded On Camera',
#   '4/10/2008',
#   '08-II02',
#   'Nearing, Holly',
#   'No',
#   'FACT FINDING',
#   'Not Stated',
#   'Not a complaint',
#   'No',
#   '4/10/2008',
#   'Internal',
#   '5/10/2008',
#   'N/A',
#   'Complainant',
#   'CPD',
#   'DOB',
#   'Gender',
#   'Address',
#   'NOT STATED ?? UNK',
#   'H Phone',
#   'Type Of Complaint',
#   'Description',
#   'Complaint Disposition',
#   'Complaint #',
#   '1',
#   'S-6 Pursuit Policy',
#   'Wrong Action by Employee',
#   'Not a complaint',
#   'Name',
#   'ID No.',
#   'Rank',
#   'Division',
#   'Officer Disposition',
#   'Action Taken',
#   'Body Cam',
#   'Officer #',
#   '1',
#   'MALONEY, J. BRIAN',
#   '942',
#   'OFFICER',
#   'Field Operations',
#   'Not a complaint',
#   'NONE',
#   'No',
#   'Date',
#   'Number',
#   'Investigator',
#   'Date Assigned',
#   'Racial',
#   'Category / Type',
#   'Location Of Occurrence',
#   'Disposition',
#   'Completed',
#   'Recorded On Camera',
#   '4/14/2008',
#   '08-05',
#   'Swenson, Jon',
#   'No',
#   'Inquiry',
#   'Not Stated',
#   'Not a complaint',
#   'No',
#   '4/16/2008',
#   'Citizen',
#   '5/14/2008',
#   'N/A',
#   'Complainant',
#   'DOB',
#   'Gender',
#   'FEMAL',
#   'Address',
#   ', Champaign IL 61821',
#   'H Phone',
#   'Type Of Complaint',
#   'Description',
#   'Complaint Disposition',
#   'Complaint #',
#   '1',
#   'R-5A3 OPERATIONS',
#   'No Action by Employee',
#   'Not a complaint',
#   'Name',
#   'ID No.',
#   'Rank',
#   'Division',
#   'Officer Disposition',
#   'Action Taken',
#   'Body Cam',
#   'Officer #',
#   '1',
#   'Sumption, R. Dustin',
#   '7108',
#   'RECRUIT OFFIC',
#   'Field Operations',
#   'PENDING',
#   'NONE',
#   'No',
#   'L.E.A. Data Technologies',
#   'ADMINISTRATIVE Database',
#   '11/10/2020 10',
#   '49',
#   '22 AM',
#   'Page 3 of 74',
#   'Complaints Detail Rpt #A-2',
#   'Champaign Police Department',
#   'Complaints By Date',
#   'Date',
#   'Number',
#   'Investigator',
#   'Date Assigned',
#   'Racial',
#   'Category / Type',
#   'Location Of Occurrence',
#   'Disposition',
#   'Completed',
#   'Recorded On Camera',
#   '4/25/2008',
#   '09-II01',
#   'Gallo, Joe',
#   'No',
#   'Inquiry',
#   'Not Stated',
#   'Not a complaint',
#   'No',
#   '10/2/2008',
#   'Internal',
#   '4/17/2009',
#   'N/A',
#   'Complainant',
#   'DOB',
#   'Gender',
#   'FEMAL',
#   'Address',
#   ', Loves Park IL 61130',
#   'H Phone',
#   'Type Of Complaint',
#   'Description',
#   'Complaint Disposition',
#   'Complaint #',
#   '1',
#   'R-1A2 CONDUCT GENERALLY',
#   'Wrong Action by Employee',
#   'Inquiry',
#   'Name',
#   'ID No.',
#   'Rank',
#   'Division',
#   'Officer Disposition',
#   'Action Taken',
#   'Body Cam',
#   'Officer #',
#   '1',
#   'No Officers Entered',
#   'Not Stated',
#   'Not Stated',
#   'Not a complaint',
#   'Not Stated',
#   'No',
#   'Date',
#   'Number',
#   'Investigator',
#   'Date Assigned',
#   'Racial',
#   'Category / Type',
#   'Location Of Occurrence',
#   'Disposition',
#   'Completed',
#   'Recorded On Camera',
#   '5/18/2008',
#   '08-08',
#   'Paulus, Michael',
#   'No',
#   'FORMAL',
#   'Not Stated',
#   'SUSTAINED',
#   'No',
#   '6/5/2008',
#   'Citizen',
#   '7/2/2008',
#   'N/A',
#   'Complainant',
#   'DOB',
#   'Gender',
#   'MALE',
#   'Address',
#   ', Champaign IL 61820',
#   'H Phone',
#   'Type Of Complaint',
#   'Description',
#   'Complaint Disposition',
#   'Complaint #',
#   '1',
#   'R-3B.4 COURTESY',
#   'COMMENT',
#   'Discourteous Conduct',
#   'SUSTAINED',
#   'Complaint #',
#   '2',
#   'R-5D Use of physical force',
#   'Wrong Action by Employee',
#   'EXONERATED',
#   'Name',
#   'ID No.',
#   'Rank',
#   'Division',
#   'Officer Disposition',
#   'Action Taken',
#   'Body Cam',
#   'Officer #',
#   '1',
#   'Bowersock, Jamie',
#   '705-MED',
#   'OFFICER',
#   'Field Operations',
#   'SUSTAINED',
#   'LETTER OF REPRIMA',
#   'No',
#   'Date',
#   'Number',
#   'Investigator',
#   'Date Assigned',
#   'Racial',
#   'Category / Type',
#   'Location Of Occurrence',
#   'Disposition',
#   'Completed',
#   'Recorded On Camera',
#   '5/26/2008',
#   '08-07',
#   'Swan, Scott',
#   'No',
#   'Inquiry',
#   'Not Stated',
#   'Inquiry',
#   'No',
#   '6/2/2008',
#   'Citizen',
#   '6/11/2008',
#   'N/A',
#   'Complainant',
#   'DOB',
#   'Gender',
#   'FEMAL',
#   'Address',
#   'Champaign IL 61821',
#   'H Phone',
#   'Type Of Complaint',
#   'Description',
#   'Complaint Disposition',
#   'Complaint #',
#   '1',
#   'R-3B COURTESY',
#   'Discourteous Conduct',
#   'Inquiry',
#   'Name',
#   'ID No.',
#   'Rank',
#   'Division',
#   'Officer Disposition',
#   'Action Taken',
#   'Body Cam',
#   'Officer #',
#   '1',
#   'Olmstead, Kevin A.',
#   '7901',
#   'RECRUIT OFFIC',
#   'Field Operations',
#   'Inquiry',
#   'NONE',
#   'No',
#   'Date',
#   'Number',
#   'Investigator',
#   'Date Assigned',
#   'Racial',
#   'Category / Type',
#   'Location Of Occurrence',
#   'Disposition',
#   'Completed',
#   'Recorded On Camera',
#   '5/31/2008',
#   '08-09',
#   'Paulus, Michael',
#   'No',
#   'FORMAL',
#   'Not Stated',
#   'EXONERATED',
#   'No',
#   '6/5/2008',
#   'Citizen',
#   '10/2/2008',
#   'N/A',
#   'Complainant',
#   'DOB',
#   'Gender',
#   'MALE',
#   'Address',
#   ', Champaign IL 61821',
#   'H Phone',
#   'Type Of Complaint',
#   'Description',
#   'Complaint Disposition',
#   'Complaint #',
#   '1',
#   'R-5B ARREST, SEARCH AND SEIZURE',
#   'Wrong Action by Employee',
#   'EXONERATED',
#   'Complaint #',
#   '2',
#   'R-5D Use of physical force',
#   'Wrong Action by Employee',
#   'EXONERATED',
#   'Name',
#   'ID No.',
#   'Rank',
#   'Division',
#   'Officer Disposition',
#   'Action Taken',
#   'Body Cam',
#   'Officer #',
#   '1',
#   'Bowersock, Jamie',
#   '705-MED',
#   'OFFICER',
#   'Field Operations',
#   'EXONERATED',
#   'NONE',
#   'No',
#   'Officer #',
#   '2',
#   'Mitchell, Rodney S.',
#   '717RES',
#   'OFFICER',
#   'Field Operations',
#   'EXONERATED',
#   'NONE',
#   'No',
#   'L.E.A. Data Technologies',
#   'ADMINISTRATIVE Database',
#   '11/10/2020 10',
#   '49',
#   '22 AM',
#   'Page 4 of 74',
#   'Complaints Detail Rpt #A-2',
#   'Champaign Police Department',
#   'Complaints By Date',
#   'Date',
#   'Number',
#   'Investigator',
#   'Date Assigned',
#   'Racial',
#   'Category / Type',
#   'Location Of Occurrence',
#   'Disposition',
#   'Completed',
#   'Recorded On Camera',
#   '6/7/2008',
#   '08-10',
#   'Yohnka, Brad',
#   'No',
#   'FORMAL',
#   'Not Stated',
#   'NOT SUSTAINED',
#   'No',
#   '6/11/2008',
#   'Citizen',
#   '6/26/2008',
#   'N/A',
#   'Complainant',
#   'DOB',
#   'Gender',
#   'MALE',
#   'Address',
#   ', Champaign IL 61821',
#   'H Phone',
#   'Type Of Complaint',
#   'Description',
#   'Complaint Disposition',
#   'Complaint #',
#   '1',
#   'R-5D Use of physical force',
#   'Wrong Action by Employee',
#   'NOT SUSTAINED',
#   'Name',
#   'ID No.',
#   'Rank',
#   'Division',
#   'Officer Disposition',
#   'Action Taken',
#   'Body Cam',
#   'Officer #',
#   '1',
#   'Mclearin, David M.',
#   '7110',
#   'RECRUIT OFFIC',
#   'Field Operations',
#   'NOT SUSTAINED',
#   'NONE',
#   'No',
#   'Date',
#   'Number',
#   'Investigator',
#   'Date Assigned',
#   'Racial',
#   'Category / Type',
#   'Location Of Occurrence',
#   'Disposition',
#   'Completed',
#   'Recorded On Camera',
#   '6/29/2008',
#   '08-11',
#   'Paulus, Michael',
#   'No',
#   'Inquiry',
#   'Not Stated',
#   'Inquiry',
#   'No',
#   '7/9/2008',
#   'Citizen',
#   '7/31/2008',
#   'N/A',
#   'Complainant',
#   'DOB',
#   'Gender',
#   'FEMAL',
#   'Address',
#   ', Champaign IL 61821',
#   'H Phone',
#   'Type Of Complaint',
#   'Description',
#   'Complaint Disposition',
#   'Complaint #',
#   '1',
#   'R-5D Use of physical force',
#   'Wrong Action by Employee',
#   'Inquiry',
#   'Name',
#   'ID No.',
#   'Rank',
#   'Division',
#   'Officer Disposition',
#   'Action Taken',
#   'Body Cam',
#   'Officer #',
#   '1',
#   'Prosser, Justin',
#   '7104',
#   'OFFICER',
#   'Field Operations',
#   'Inquiry',
#   'NONE',
#   'No',
#   ...],
#  {'Report Criteria': [[44.4005,
#     31.16701584000009,
#     104.49586512000002,
#     41.16125584000008,
#     1.0]],
#   'Complaints Occurred Between': [[113.1612,
#     31.009535712,
#     221.78659571199998,
#     39.00492771200004,
#     1.0]],
#   '1/1/2008 AND 11/20/2020': [[226.2959968,
#     31.009535712,
#     318.8506545920001,
#     39.00492771200004,
#     1.0]],
#   'Complaints Detail Rpt #A-2': [[44.1611,
#     46.16421584,
#     156.19653039999997,
#     56.15845583999999,
#     1.0],
#    [44.1611, 31.16701584000009, 156.19653039999997, 41.16125584000008, 2.0],
#    [44.1611, 31.16701584000009, 156.19653039999997, 41.16125584000008, 3.0],
#    [44.1611, 31.16701584000009, 156.19653039999997, 41.16125584000008, 4.0],
#   '08-09': [[100.68542750000002,
#     423.0877632,
#     123.71805470000002,
#     432.09896319999996,
#     4.0]],
#   'R-5B ARREST, SEARCH AND SEIZURE': [[229.9181,
#     471.3293632,
#     394.6969032,
#     480.3405632,
#     4.0]],
#   'Mitchell, Rodney S.': [[229.66497249999992,
#     528.3307632,
#     307.31448289999986,
#     537.3419632,
#     4.0]],
#   '717RES': [[370.53647249999995,
#     528.3307632,
#     404.20231569999993,
#     537.3419632,
#     4.0]],
#   'Page 4 of 74': [[711.5997, 578.1750192, 758.097492, 587.1862192, 4.0]],
#   '6/7/2008': [[52.04782750000004,
#     88.04906319999986,
#     87.33568670000005,
#     97.0602631999999,
#     5.0]],
#   '08-10': [[100.68542750000005,
#     88.04906319999986,
#     123.71805470000005,
#     97.0602631999999,
#     5.0]],
#   'Yohnka, Brad': [[160.61342750000006,
#     88.04906319999986,
#     215.36547870000007,
#     97.0602631999999,
#     5.0]],
#   '6/26/2008': [[638.942632,
#     96.29019571200001,
#     674.570098752,
#     104.285587712,
#     5.0]],
#   'Mclearin, David M.': [[229.66497249999992,
#     163.1689632,
#     304.0704508999999,
#     172.18016319999998,
#     5.0]],
#   '7110': [[370.53647249999995,
#     163.1689632,
#     390.68551569999994,
#     172.18016319999998,
#     5.0]],
#   '6/29/2008': [[49.52662750000002,
#     194.85026320000003,
#     89.68053470000002,
#     203.8614632,
#     5.0]],
#   '08-11': [[100.68542750000002,
#     194.85026320000003,
#     123.71805470000002,
#     203.8614632,
#     5.0]],
#   '7/9/2008': [[244.5578,
#     203.69013571199997,
#     275.707847232,
#     211.68552771199995,
#     5.0]],
#   '7/31/2008': [[638.9472000000001,
#     202.97182411199998,
#     674.5746667520001,
#     210.96721611199996,
#     5.0]],
#   'Prosser, Justin': [[229.66497249999992,
#     269.9696632,
#     289.5534076999999,
#     278.9808632,
#     5.0]],
#   '7104': [[370.53647249999995,
#     269.9696632,
#     390.68551569999994,
#     278.9808632,
#     5.0]],
#   '7/3/2008': [[52.04782750000004,
#     301.5284132,
#     87.33568670000005,
#     310.53961319999996,
#     5.0]],
#   '08-12': [[100.68542750000005,
#     301.5284132,
#     123.71805470000005,
#     310.53961319999996,
#     5.0]],
#   'shaffer, david': [[160.61342750000006,
#     301.5284132,
#     214.82480670000007,
#     310.53961319999996,
#     5.0]],
#   '7/11/2008': [[240.1178, 310.489535712, 275.745266752, 318.484927712, 5.0]],
#   '10/6/2008': [[638.942632,
#     309.650200112,
#     674.570098752,
#     317.645592112,
#     5.0]],
#   'R-5C2 PERSONS IN CUSTODY': [[229.9181,
#     349.6490632,
#     360.1840072,
#     358.66026320000003,
#     5.0]],
#   'Briggs, Mark D.': [[229.66497249999992,
#     391.6499632,
#     291.81521889999993,
#     400.66116320000003,
#     5.0]],
#   '785RESI': [[370.53647249999995,
#     391.6499632,
#     406.64435089999995,
#     400.66116320000003,
#     5.0]],
#   'Senior OFFICER': [[415.6787,
#     391.608235712,
#     476.219808224,
#     399.603627712,
#     5.0]],
#   'Young, Von D.III': [[229.66497249999992,
#     416.4904632,
#     295.7801468999999,
#     425.5016632,
#     5.0]],
#   '719': [[370.53647249999995,
#     416.4904632,
#     385.7293556999999,
#     425.5016632,
#     5.0]],
#   '7/13/2008': [[49.52662750000002,
#     448.04925819999994,
#     89.68053470000002,
#     457.06045819999997,
#     5.0]],
#   '08-13': [[100.68542750000002,
#     448.04925819999994,
#     123.71805470000002,
#     457.06045819999997,
#     5.0]],
#   '7/16/2008': [[240.1178,
#     456.887235712,
#     275.745266752,
#     464.88262771200004,
#     5.0]],
#   '8/28/2008': [[638.942632,
#     456.169875712,
#     674.570098752,
#     464.165267712,
#     5.0]]})

# %%
# predict fields 
fields = twix.predict_field(pdf_paths)
fields[:10]
# Out:
# Field prediction starts...
# perfect match starts...
# cluster pruning starts...
# re-clustering starts...
# ['Complaints Detail Rpt #A-2',
#  'Champaign Police Department',
#  'Complaints By Date',
#  'Date',
#  'Number',
#  'Investigator',
#  'Date Assigned',
#  'Racial',
#  'Category / Type',
#  'Location Of Occurrence']

# %%
# predict template 
template = twix.predict_template(pdf_paths)
template
# Out:
# Template prediction starts...
# row align of 2 and 31: 0
# initial row labels and probs:
# 0 {'K': 0.001, 'V': 1.001, 'KV': 0.001, 'M': 0.002}
# ['Report Criteria', 'Complaints Occurred Between', '1/1/2008 AND 11/20/2020']
# 1 {'K': 1.001, 'V': 0.001, 'KV': 0.001, 'M': 0.002}
# ['Complaints Detail Rpt #A-2', 'Champaign Police Department']
# 2 {'K': 0.001, 'V': 0.001, 'KV': 0.001, 'M': 1}
# ['Complaints By Date']
# 3 {'K': 1.001, 'V': 0.001, 'KV': 0.001, 'M': 0.002}
# ['Date', 'Number', 'Investigator', 'Date Assigned', 'Racial', 'Category / Type', 'Location Of Occurrence', 'Disposition', 'Completed', 'Recorded On Camera']
# 4 {'K': 0.001, 'V': 1.001, 'KV': 0.001, 'M': 0.002}
# ['1/27/2008', '08-01', 'Swenson, Jon', 'No', 'FORMAL', 'Not Stated', 'SUSTAINED', 'No']
# 5 {'K': 0.001, 'V': 1.001, 'KV': 0.001, 'M': 0.002}
# ['1/30/2008', 'Citizen', '2/7/2008', 'N/A']
# 6 {'K': 0.501, 'V': 0.001, 'KV': 0.502, 'M': 0.002}
# ['Complainant', 'DOB', 'Gender', 'FEMAL', 'Address', 'Terr, Champaign IL 61820', 'H Phone']
# 7 {'K': 1.001, 'V': 0.001, 'KV': 0.001, 'M': 0.002}
# ['Type Of Complaint', 'Description', 'Complaint Disposition']
# 8 {'K': 0.001, 'V': 0.801, 'KV': 0.201, 'M': 0.002}
# ['Complaint #', '1', 'R-3B.1 Courtesy', 'Profanity', 'Discourteous Conduct', 'SUSTAINED']
# 9 {'K': 1.001, 'V': 0.001, 'KV': 0.001, 'M': 0.002}
# ['Name', 'ID No.', 'Rank', 'Division', 'Officer Disposition', 'Action Taken', 'Body Cam']
# 10 {'K': 0.001, 'V': 1.001, 'KV': 0.001, 'M': 0.002}
# ['Officer #', '1', 'Griffet, David I.', '914', 'SERGEANT', 'Field Operations', 'SUSTAINED', 'COUNSELING', 'No']
# 11 {'K': 1.001, 'V': 0.001, 'KV': 0.001, 'M': 0.002}
# ['Date', 'Number', 'Investigator', 'Date Assigned', 'Racial', 'Category / Type', 'Location Of Occurrence', 'Disposition', 'Completed', 'Recorded On Camera']
# 12 {'K': 0.001, 'V': 1.001, 'KV': 0.001, 'M': 0.002}
# ['2/24/2008', '08-02', 'Swan, Scott', 'No', 'FORMAL', 'Not Stated', 'SUSTAINED', 'No']
# 13 {'K': 0.001, 'V': 1.001, 'KV': 0.001, 'M': 0.002}
# ['2/27/2008', 'Citizen', '3/17/2008', 'N/A']
# 14 {'K': 0.501, 'V': 0.001, 'KV': 0.502, 'M': 0.002}
# ['Complainant', 'DOB', 'Gender', 'FEMAL', 'Address', ', Champaign IL 61821', 'H Phone']
# 15 {'K': 1.001, 'V': 0.001, 'KV': 0.001, 'M': 0.002}
# ['Type Of Complaint', 'Description', 'Complaint Disposition']
# 16 {'K': 0.001, 'V': 0.801, 'KV': 0.201, 'M': 0.002}
# ['Complaint #', '1', 'R-3B.1 Courtesy', 'Profanity', 'Discourteous Conduct', 'NOT SUSTAINED']
# 17 {'K': 0.001, 'V': 0.801, 'KV': 0.201, 'M': 0.002}
# ['Complaint #', '2', 'R-3B.4 COURTESY', 'COMMENT', 'Discourteous Conduct', 'SUSTAINED']
# 18 {'K': 0.001, 'V': 0.751, 'KV': 0.251, 'M': 0.002}
# ['Complaint #', '3', 'R-5D Use of physical force', 'Wrong Action by Employee', 'EXONERATED']
# 19 {'K': 1.001, 'V': 0.001, 'KV': 0.001, 'M': 0.002}
# ['Name', 'ID No.', 'Rank', 'Division', 'Officer Disposition', 'Action Taken', 'Body Cam']
# 20 {'K': 0.001, 'V': 1.001, 'KV': 0.001, 'M': 0.002}
# ['Officer #', '1', 'Petrilli, Thomas P.', '939', 'Senior', 'Officer', 'Field Operations', 'SUSTAINED', 'COUNSELING', 'No']
# 21 {'K': 1.001, 'V': 0.001, 'KV': 0.001, 'M': 0.002}
# ['Date', 'Number', 'Investigator', 'Date Assigned', 'Racial', 'Category / Type', 'Location Of Occurrence', 'Disposition', 'Completed', 'Recorded On Camera']
# 22 {'K': 0.001, 'V': 1.001, 'KV': 0.001, 'M': 0.002}
# ['3/5/2008', '08-03', 'Paulus, Michael', 'No', 'FORMAL', 'Not Stated', 'NOT SUSTAINED', 'No']
# 23 {'K': 0.001, 'V': 1.001, 'KV': 0.001, 'M': 0.002}
# ['3/10/2008', 'Citizen', '4/28/2008', 'N/A']
# 24 {'K': 0.401, 'V': 0.001, 'KV': 0.601, 'M': 0.002}
# ['Complainant', 'DOB', 'Gender', 'MALE', 'Address', ', Champaign IL 61821', 'H Phone', '(']
# 25 {'K': 1.001, 'V': 0.001, 'KV': 0.001, 'M': 0.002}
# ['Type Of Complaint', 'Description', 'Complaint Disposition']
# 26 {'K': 0.001, 'V': 0.801, 'KV': 0.201, 'M': 0.002}
# ['Complaint #', '1', 'R-3B.2 Courtesy', 'Rude', 'Discourteous Conduct', 'UNFOUNDED']
# 27 {'K': 0.001, 'V': 0.801, 'KV': 0.201, 'M': 0.002}
# ['Complaint #', '2', 'R-3B.2 Courtesy', 'Rude', 'Discourteous Conduct', 'NOT SUSTAINED']
# 28 {'K': 1.001, 'V': 0.001, 'KV': 0.001, 'M': 0.002}
# ['Name', 'ID No.', 'Rank', 'Division', 'Officer Disposition', 'Action Taken', 'Body Cam']
# 29 {'K': 0.001, 'V': 1.001, 'KV': 0.001, 'M': 0.002}
# ['Officer #', '1', 'Shepard, Charles F.', '921RET', 'SERGEANT', 'Field Operations', 'NOT SUSTAINED', 'NONE', 'No']
# 30 {'K': 0.001, 'V': 1.001, 'KV': 0.001, 'M': 0.002}
# ['L.E.A. Data Technologies', 'ADMINISTRATIVE Database', '11/10/2020 10', '49', '22 AM', 'Page 1 of 74']
# 31 {'K': 1.001, 'V': 0.001, 'KV': 0.001, 'M': 0.002}
# ['Complaints Detail Rpt #A-2', 'Champaign Police Department']
# 32 {'K': 0.001, 'V': 0.001, 'KV': 0.001, 'M': 1}
# ['Complaints By Date']
# 33 {'K': 1.001, 'V': 0.001, 'KV': 0.001, 'M': 0.002}
# ['Date', 'Number', 'Investigator', 'Date Assigned', 'Racial', 'Category / Type', 'Location Of Occurrence', 'Disposition', 'Completed', 'Recorded On Camera']
# 34 {'K': 0.001, 'V': 1.001, 'KV': 0.001, 'M': 0.002}
# ['3/14/2008', '08-II01', 'Swan, Scott', 'No', 'FORMAL', 'Not Stated', 'SUSTAINED', 'No']
# 35 {'K': 0.001, 'V': 1.001, 'KV': 0.001, 'M': 0.002}
# ['3/14/2008', 'Internal', '3/14/2008', 'N/A']
# 36 {'K': 0.501, 'V': 0.001, 'KV': 0.502, 'M': 0.002}
# ['Complainant', 'DOB', 'Gender', 'FEMAL', 'Address', ', Champaign IL 61821', 'H Phone']
# 37 {'K': 1.001, 'V': 0.001, 'KV': 0.001, 'M': 0.002}
# ['Type Of Complaint', 'Description', 'Complaint Disposition']
# 38 {'K': 0.001, 'V': 0.801, 'KV': 0.201, 'M': 0.002}
# ['Complaint #', '1', 'R-3B.2 Courtesy', 'Rude', 'Discourteous Conduct', 'SUSTAINED']
# 39 {'K': 1.001, 'V': 0.001, 'KV': 0.001, 'M': 0.002}
# ['Name', 'ID No.', 'Rank', 'Division', 'Officer Disposition', 'Action Taken', 'Body Cam']
# 40 {'K': 0.001, 'V': 1.001, 'KV': 0.001, 'M': 0.002}
# ['Officer #', '1', 'Wilberg, Richard W.', '799RESI', 'Senior', 'Officer', 'Field Operations', 'SUSTAINED', 'COUNSELING', 'No']
# 41 {'K': 0.001, 'V': 0.499, 'KV': 0.001, 'M': 0.5}
# ['G']
# 42 {'K': 1.001, 'V': 0.001, 'KV': 0.001, 'M': 0.002}
# ['Date', 'Number', 'Investigator', 'Date Assigned', 'Racial', 'Category / Type', 'Location Of Occurrence', 'Disposition', 'Completed', 'Recorded On Camera']
# 43 {'K': 0.001, 'V': 1.001, 'KV': 0.001, 'M': 0.002}
# ['3/18/2008', '08-06', 'Gallo, Joe', 'No', 'FORMAL', 'Not Stated', 'SUSTAINED', 'No']
# 44 {'K': 0.001, 'V': 1.001, 'KV': 0.001, 'M': 0.002}
# ['4/17/2008', 'Citizen', '4/23/2008', 'N/A']
# 45 {'K': 0.501, 'V': 0.001, 'KV': 0.502, 'M': 0.002}
# ['Complainant', 'DOB', 'Gender', 'MALE', 'Address', ', Champaign IL 61821', 'H Phone']
# 46 {'K': 1.001, 'V': 0.001, 'KV': 0.001, 'M': 0.002}
# ['Type Of Complaint', 'Description', 'Complaint Disposition']
# 47 {'K': 0.001, 'V': 0.801, 'KV': 0.201, 'M': 0.002}
# ['Complaint #', '1', 'R-3B.1 Courtesy', 'Profanity', 'Discourteous Conduct', 'NOT SUSTAINED']
# 48 {'K': 0.001, 'V': 0.801, 'KV': 0.201, 'M': 0.002}
# ['Complaint #', '2', 'R-3B.4 COURTESY', 'COMMENT', 'Discourteous Conduct', 'SUSTAINED']
# 49 {'K': 1.001, 'V': 0.001, 'KV': 0.001, 'M': 0.002}
# ['Name', 'ID No.', 'Rank', 'Division', 'Officer Disposition', 'Action Taken', 'Body Cam']
# 50 {'K': 0.001, 'V': 1.001, 'KV': 0.001, 'M': 0.002}
# ['Officer #', '1', 'Kelly, Patrick M.', '722-Ret', 'DETECTIVE', 'Operations Supp', 'SUSTAINED', 'COUNSELING', 'No']
# 51 {'K': 1.001, 'V': 0.001, 'KV': 0.001, 'M': 0.002}
# ['Date', 'Number', 'Investigator', 'Date Assigned', 'Racial', 'Category / Type', 'Location Of Occurrence', 'Disposition', 'Completed', 'Recorded On Camera']
# 52 {'K': 0.001, 'V': 1.001, 'KV': 0.001, 'M': 0.002}
# ['3/22/2008', '08-04a', 'Swenson, Jon', 'No', 'FORMAL', 'Not Stated', 'UNFOUNDED', 'No']
# 53 {'K': 0.001, 'V': 1.001, 'KV': 0.001, 'M': 0.002}
# ['4/16/2008', 'Citizen', '5/1/2008', 'N/A']
# 54 {'K': 0.401, 'V': 0.001, 'KV': 0.601, 'M': 0.002}
# ['Complainant', 'DOB', 'Gender', 'MALE', 'Address', 'Ct, Rantoul IL 61866', 'H Phone', '(']
# 55 {'K': 1.001, 'V': 0.001, 'KV': 0.001, 'M': 0.002}
# ['Type Of Complaint', 'Description', 'Complaint Disposition']
# 56 {'K': 0.001, 'V': 0.751, 'KV': 0.251, 'M': 0.002}
# ['Complaint #', '1', 'R-5D Use of physical force', 'Wrong Action by Employee', 'UNFOUNDED']
# 57 {'K': 1.001, 'V': 0.001, 'KV': 0.001, 'M': 0.002}
# ['Name', 'ID No.', 'Rank', 'Division', 'Officer Disposition', 'Action Taken', 'Body Cam']
# 58 {'K': 0.001, 'V': 1.001, 'KV': 0.001, 'M': 0.002}
# ['Officer #', '1', 'Lack, Aaron V.', '920', 'SERGEANT', 'Field Operations', 'UNFOUNDED', 'NONE', 'No']
# 59 {'K': 0.3343333333333333, 'V': 0.501, 'KV': 0.16766666666666666, 'M': 0.002}
# ['Officer #', '2', 'MULTIPLE OFFICERS/EMPLOY', 'NOT STATED', 'NOT ENTERED', 'UNFOUNDED', 'NONE', 'No']
# 60 {'K': 1.001, 'V': 0.001, 'KV': 0.001, 'M': 0.002}
# ['Date', 'Number', 'Investigator', 'Date Assigned', 'Racial', 'Category / Type', 'Location Of Occurrence', 'Disposition', 'Completed', 'Recorded On Camera']
# 61 {'K': 0.001, 'V': 1.001, 'KV': 0.001, 'M': 0.002}
# ['3/22/2008', '08-04b', 'Swenson, Jon', 'No', 'FORMAL', 'Not Stated', 'UNFOUNDED', 'No']
# 62 {'K': 0.001, 'V': 1.001, 'KV': 0.001, 'M': 0.002}
# ['4/16/2008', 'Citizen', '5/1/2008', 'N/A']
# 63 {'K': 0.501, 'V': 0.001, 'KV': 0.502, 'M': 0.002}
# ['Complainant', 'DOB', 'Gender', 'FEMAL', 'Address', ', CHICAGO IL 60644-2803', 'H Phone']
# 64 {'K': 1.001, 'V': 0.001, 'KV': 0.001, 'M': 0.002}
# ['Type Of Complaint', 'Description', 'Complaint Disposition']
# 65 {'K': 0.001, 'V': 0.751, 'KV': 0.251, 'M': 0.002}
# ['Complaint #', '1', 'R-5D Use of physical force', 'Wrong Action by Employee', 'UNFOUNDED']
# 66 {'K': 1.001, 'V': 0.001, 'KV': 0.001, 'M': 0.002}
# ['Name', 'ID No.', 'Rank', 'Division', 'Officer Disposition', 'Action Taken', 'Body Cam']
# 67 {'K': 0.3343333333333333, 'V': 0.501, 'KV': 0.16766666666666666, 'M': 0.002}
# ['Officer #', '1', 'MULTIPLE OFFICERS/EMPLOY', 'NOT STATED', 'NOT ENTERED', 'UNFOUNDED', 'NONE', 'No']
# 68 {'K': 0.001, 'V': 1.001, 'KV': 0.001, 'M': 0.002}
# ['L.E.A. Data Technologies', 'ADMINISTRATIVE Database', '11/10/2020 10', '49', '22 AM', 'Page 2 of 74']
# 69 {'K': 1.001, 'V': 0.001, 'KV': 0.001, 'M': 0.002}
# ['Complaints Detail Rpt #A-2', 'Champaign Police Department']
# 70 {'K': 0.001, 'V': 0.001, 'KV': 0.001, 'M': 1}
# ['Complaints By Date']
# 71 {'K': 1.001, 'V': 0.001, 'KV': 0.001, 'M': 0.002}
# ['Date', 'Number', 'Investigator', 'Date Assigned', 'Racial', 'Category / Type', 'Location Of Occurrence', 'Disposition', 'Completed', 'Recorded On Camera']
# 72 {'K': 0.001, 'V': 1.001, 'KV': 0.001, 'M': 0.002}
# ['3/22/2008', '08-04c', 'Swenson, Jon', 'No', 'FORMAL', 'Not Stated', 'EXONERATED', 'No']
# Restricted license - for non-production use only - expires 2026-11-23
# Gurobi Optimizer version 12.0.0 build v12.0.0rc1 (mac64[arm] - Darwin 23.2.0 23C71)
#
# CPU model: Apple M1 Pro
# Thread count: 10 physical cores, 10 logical processors, using up to 10 threads
#
# Optimize a model with 219 rows, 292 columns and 730 nonzeros
# Model fingerprint: 0x278a8232
# Variable types: 0 continuous, 292 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e-03, 7e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective -391.1291911
# Presolve removed 219 rows and 292 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 10 available processors)
#
# Solution count 2: -65.0652 -391.129
# No other solutions better than -65.0652
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -6.506523843114e+01, best bound -6.506523843114e+01, gap 0.0000%
# labels after ILP:
# {0: 'M', 1: 'M', 2: 'M', 3: 'K', 4: 'V', 5: 'V', 6: 'KV', 7: 'K', 8: 'V', 9: 'K', 10: 'V', 11: 'K', 12: 'V', 13: 'V', 14: 'KV', 15: 'K', 16: 'V', 17: 'V', 18: 'V', 19: 'K', 20: 'V', 21: 'K', 22: 'M', 23: 'V', 24: 'KV', 25: 'K', 26: 'V', 27: 'V', 28: 'K', 29: 'V', 30: 'V', 31: 'M', 32: 'M', 33: 'K', 34: 'V', 35: 'V', 36: 'KV', 37: 'K', 38: 'V', 39: 'K', 40: 'V', 41: 'M', 42: 'K', 43: 'V', 44: 'V', 45: 'KV', 46: 'K', 47: 'V', 48: 'V', 49: 'K', 50: 'V', 51: 'K', 52: 'M', 53: 'V', 54: 'KV', 55: 'K', 56: 'V', 57: 'K', 58: 'V', 59: 'V', 60: 'K', 61: 'M', 62: 'V', 63: 'KV', 64: 'K', 65: 'V', 66: 'K', 67: 'V', 68: 'V', 69: 'M', 70: 'M', 71: 'M', 72: 'M'}
# {0: [3, 4, 5], 1: [6], 2: [7, 8], 3: [9, 10], 4: [11, 12, 13], 5: [14], 6: [15, 16, 17, 18], 7: [19, 20], 8: [21, 23], 9: [24], 10: [25, 26, 27], 11: [28, 29, 30], 12: [33, 34, 35], 13: [36], 14: [37, 38], 15: [39, 40], 16: [42, 43, 44], 17: [45], 18: [46, 47, 48], 19: [49, 50], 20: [51, 53], 21: [54], 22: [55, 56], 23: [57, 58, 59], 24: [60, 62], 25: [63], 26: [64, 65], 27: [66, 67, 68]}
# {0: 'table', 1: 'kv', 2: 'table', 3: 'table', 4: 'table', 5: 'kv', 6: 'table', 7: 'table', 8: 'table', 9: 'kv', 10: 'table', 11: 'table', 12: 'table', 13: 'kv', 14: 'table', 15: 'table', 16: 'table', 17: 'kv', 18: 'table', 19: 'table', 20: 'table', 21: 'kv', 22: 'table', 23: 'table', 24: 'table', 25: 'kv', 26: 'table', 27: 'table'}
# [{'type': 'table',
#   'fields': ['Date',
#    'Number',
#    'Investigator',
#    'Date Assigned',
#    'Racial',
#    'Category / Type',
#    'Location Of Occurrence',
#    'Disposition',
#    'Completed',
#    'Recorded On Camera'],
#   'bid': [0],
#   'child': -1,
#   'node_id': 0},
#  {'type': 'kv',
#   'fields': ['Address', 'H Phone', 'Gender', 'DOB', 'Complainant'],
#   'bid': [1],
#   'child': -1,
#   'node_id': 1},
#  {'type': 'table',
#   'fields': ['Type Of Complaint', 'Description', 'Complaint Disposition'],
#   'bid': [2],
#   'child': -1,
#   'node_id': 2},
#  {'type': 'table',
#   'fields': ['Name',
#    'ID No.',
#    'Rank',
#    'Division',
#    'Officer Disposition',
#    'Action Taken',
#    'Body Cam'],
#   'bid': [3],
#   'child': -1,
#   'node_id': 3}]

# %%
# extract data based on template 
extraction_objects = twix.extract_data(pdf_paths)
extraction_objects
# Out:
# Record seperation starts...
# Totally 269 records...
# Block seperation starts...
# Record 0...
# Record 1...
# Record 2...
# Record 3...
# Record 4...
# Record 5...
# Record 6...
# Record 7...
# Record 8...
# Record 9...
# Record 10...
# Record 11...
# Record 12...
# Record 13...
# Record 14...
# Record 15...
# Record 16...
# Record 17...
# Record 18...
# Record 19...
# Record 20...
# Record 21...
# Record 22...
# Record 23...
# Record 24...
# Record 25...
# Record 26...
# Record 27...
# Record 28...
# Record 29...
# Record 30...
# Record 31...
# Record 32...
# Record 33...
# Record 34...
# Record 35...
# Record 36...
# Record 37...
# Record 38...
# Record 39...
# Record 40...
# Record 41...
# Record 42...
# Record 43...
# Record 44...
# Record 45...
# Record 46...
# Record 47...
# Record 48...
# Record 49...
# Record 50...
# Record 51...
# Record 52...
# Record 53...
# Record 54...
# Record 55...
# Record 56...
# Record 57...
# Record 58...
# Record 59...
# Record 60...
# Record 61...
# Record 62...
# Record 63...
# Record 64...
# Record 65...
# Record 66...
# Record 67...
# Record 68...
# Record 69...
# Record 70...
# Record 71...
# Record 72...
# Record 73...
# Record 74...
# Record 75...
# Record 76...
# Record 77...
# Record 78...
# Record 79...
# Record 80...
# Record 81...
# Record 82...
# Record 83...
# Record 84...
# Record 85...
# Record 86...
# Record 87...
# Record 88...
# Record 89...
# Record 90...
# Record 91...
# Record 92...
# Record 93...
# Record 94...
# Record 95...
# Record 96...
# Record 97...
# Record 98...
# Record 99...
# Record 100...
# Record 101...
# Record 102...
# Record 103...
# Record 104...
# Record 105...
# Record 106...
# Record 107...
# Record 108...
# Record 109...
# Record 110...
# Record 111...
# Record 112...
# Record 113...
# Record 114...
# Record 115...
# Record 116...
# Record 117...
# Record 118...
# Record 119...
# Record 120...
# Record 121...
# Record 122...
# Record 123...
# Record 124...
# Record 125...
# Record 126...
# Record 127...
# Record 128...
# Record 129...
# Record 130...
# Record 131...
# Record 132...
# Record 133...
# Record 134...
# Record 135...
# Record 136...
# Record 137...
# Record 138...
# Record 139...
# Record 140...
# Record 141...
# Record 142...
# Record 143...
# Record 144...
# Record 145...
# Record 146...
# Record 147...
# Record 148...
# Record 149...
# Record 150...
# Record 151...
# Record 152...
# Record 153...
# Record 154...
# Record 155...
# Record 156...
# Record 157...
# Record 158...
# Record 159...
# Record 160...
# Record 161...
# Record 162...
# Record 163...
# Record 164...
# Record 165...
# Record 166...
# Record 167...
# Record 168...
# Record 169...
# Record 170...
# Record 171...
# Record 172...
# Record 173...
# Record 174...
# Record 175...
# Record 176...
# Record 177...
# Record 178...
# Record 179...
# Record 180...
# Record 181...
# Record 182...
# Record 183...
# Record 184...
# Record 185...
# Record 186...
# Record 187...
# Record 188...
# Record 189...
# Record 190...
# Record 191...
# Record 192...
# Record 193...
# Record 194...
# Record 195...
# Record 196...
# Record 197...
# Record 198...
# Record 199...
# Record 200...
# Record 201...
# Record 202...
# Record 203...
# Record 204...
# Record 205...
# Record 206...
# Record 207...
# Record 208...
# Record 209...
# Record 210...
# Record 211...
# Record 212...
# Record 213...
# Record 214...
# Record 215...
# Record 216...
# Record 217...
# Record 218...
# Record 219...
# Record 220...
# Record 221...
# Record 222...
# Record 223...
# Record 224...
# Record 225...
# Record 226...
# Record 227...
# Record 228...
# Record 229...
# Record 230...
# Record 231...
# Record 232...
# Record 233...
# Record 234...
# Record 235...
# Record 236...
# Record 237...
# Record 238...
# Record 239...
# Record 240...
# Record 241...
# Record 242...
# Record 243...
# Record 244...
# Record 245...
# Record 246...
# Record 247...
# Record 248...
# Record 249...
# Record 250...
# Record 251...
# Record 252...
# Record 253...
# Record 254...
# Record 255...
# Record 256...
# Record 257...
# Record 258...
# Record 259...
# Record 260...
# Record 261...
# Record 262...
# Record 263...
# Record 264...
# Record 265...
# Record 266...
# Record 267...
# Record 268...
# Data extraction starts...
# {'data_file': [{'id': 0,
#    'content': [{'type': 'table',
#      'content': [{'Date': '1/27/2008',
#        'Number': '08-01',
#        'Investigator': 'Swenson, Jon',
#        'Date Assigned': 'missing',
#        'Racial': 'No',
#        'Category / Type': 'FORMAL',
#        'Location Of Occurrence': 'Not Stated',
#        'Disposition': 'SUSTAINED',
#        'Completed': 'missing',
#        'Recorded On Camera': 'No'},
#       {'Date': 'missing',
#        'Number': 'missing',
#        'Investigator': 'missing',
#        'Date Assigned': '1/30/2008',
#        'Racial': 'missing',
#        'Category / Type': 'Citizen',
#        'Location Of Occurrence': 'missing',
#        'Disposition': 'missing',
#        'Completed': '2/7/2008',
#        'Recorded On Camera': 'N/A'}]},
#     {'type': 'kv',
#      'content': [{'Complainant': 'missing'},
#       {'DOB': 'missing'},
#       {'Gender': 'FEMAL'},
#       {'Address': 'Terr, Champaign IL 61820'},
#       {'H Phone': 'missing'}]},
#     {'type': 'table',
#      'content': [{'Type Of Complaint': 'R-3B.1 Courtesy',
#        'Description': 'Discourteous Conduct',
#        'Complaint Disposition': 'SUSTAINED'}]},
#     {'type': 'table',
#      'content': [{'Name': 'Griffet, David I.',
#        'ID No.': '914',
#        'Rank': 'SERGEANT',
#        'Division': 'Field Operations',
#        'Officer Disposition': 'SUSTAINED',
#        'Action Taken': 'COUNSELING',
#        'Body Cam': 'No'}]}]},
#   {'id': 1,
#    'content': [{'type': 'table',
#      'content': [{'Date': '2/24/2008',
#        'Number': '08-02',
#        'Investigator': 'Swan, Scott',
#        'Date Assigned': 'missing',
#        'Racial': 'No',
#        'Category / Type': 'FORMAL',
#        'Location Of Occurrence': 'Not Stated',
#        'Disposition': 'SUSTAINED',
#        'Completed': 'missing',
#        'Recorded On Camera': 'No'},
#       {'Date': 'missing',
#        'Number': 'missing',
#        'Investigator': 'missing',
#        'Date Assigned': '2/27/2008',
#        'Racial': 'missing',
#        'Category / Type': 'Citizen',
#        'Location Of Occurrence': 'missing',
#        'Disposition': 'missing',
#        'Completed': '3/17/2008',
#        'Recorded On Camera': 'N/A'}]},
#     {'type': 'kv',
#      'content': [{'Complainant': 'missing'},
#       {'DOB': 'missing'},
#       {'Gender': 'FEMAL'},
#       {'Address': ', Champaign IL 61821'},
#       {'H Phone': 'missing'}]},
#     {'type': 'table',
#      'content': [{'Type Of Complaint': 'R-3B.1 Courtesy',
#        'Description': 'Discourteous Conduct',
#        'Complaint Disposition': 'NOT SUSTAINED'},
#       {'Type Of Complaint': 'R-3B.4 COURTESY',
#        'Description': 'Discourteous Conduct',
#        'Complaint Disposition': 'SUSTAINED'},
#       {'Type Of Complaint': 'R-5D Use of physical force',
#        'Description': 'Wrong Action by Employee',
#        'Complaint Disposition': 'EXONERATED'}]},
#     {'type': 'table',
#      'content': [{'Name': 'Petrilli, Thomas P.',
#        'ID No.': '939',
#        'Rank': 'Senior',
#        'Division': 'Field Operations',
#        'Officer Disposition': 'SUSTAINED',
#        'Action Taken': 'COUNSELING',
#        'Body Cam': 'No'}]}]},
#   {'id': 2,
#    'content': [{'type': 'table',
#      'content': [{'Date': 'missing',
#        'Number': 'missing',
#        'Investigator': 'missing',
#        'Date Assigned': '3/10/2008',
#        'Racial': 'missing',
#        'Category / Type': 'Citizen',
#        'Location Of Occurrence': 'missing',
#        'Disposition': 'missing',
#        'Completed': '4/28/2008',
#        'Recorded On Camera': 'N/A'}]},
#     {'type': 'kv',
#      'content': [{'Complainant': 'missing'},
#       {'DOB': 'missing'},
#       {'Gender': 'MALE'},
#       {'Address': ', Champaign IL 61821'},
#       {'H Phone': '('}]},
#     {'type': 'table',
#      'content': [{'Type Of Complaint': 'R-3B.2 Courtesy',
#        'Description': 'Discourteous Conduct',
#        'Complaint Disposition': 'UNFOUNDED'},
#       {'Type Of Complaint': 'R-3B.2 Courtesy',
#        'Description': 'Discourteous Conduct',
#        'Complaint Disposition': 'NOT SUSTAINED'}]},
#     {'type': 'table',
#      'content': [{'Name': 'Shepard, Charles F.',
#        'ID No.': '921RET',
#        'Rank': 'SERGEANT',
#        'Division': 'Field Operations',
#        'Officer Disposition': 'NOT SUSTAINED',
#        'Action Taken': 'NONE',
#        'Body Cam': 'No'}]}]},
#   {'id': 3,
#    'content': [{'type': 'table',
#      'content': [{'Date': '3/14/2008',
#        'Number': '08-II01',
#        'Investigator': 'Swan, Scott',
#        'Date Assigned': 'missing',
#        'Racial': 'No',
#        'Category / Type': 'FORMAL',
#        'Location Of Occurrence': 'Not Stated',
#        'Disposition': 'SUSTAINED',
#        'Completed': 'missing',
#        'Recorded On Camera': 'No'},
#       {'Date': 'missing',
#        'Number': 'missing',
#        'Investigator': 'missing',
#        'Date Assigned': '3/14/2008',
#        'Racial': 'missing',
#        'Category / Type': 'Internal',
#        'Location Of Occurrence': 'missing',
#        'Disposition': 'missing',
#        'Completed': '3/14/2008',
#        'Recorded On Camera': 'N/A'}]},
#     {'type': 'kv',
#      'content': [{'Complainant': 'missing'},
#       {'DOB': 'missing'},
#       {'Gender': 'FEMAL'},
#       {'Address': ', Champaign IL 61821'},
#       {'H Phone': 'missing'}]},
#     {'type': 'table',
#      'content': [{'Type Of Complaint': 'R-3B.2 Courtesy',
#        'Description': 'Discourteous Conduct',
#        'Complaint Disposition': 'SUSTAINED'}]},
#     {'type': 'table',
#      'content': [{'Name': 'Wilberg, Richard W.',
#        'ID No.': '799RESI',
#        'Rank': 'Senior',
#        'Division': 'Field Operations',
#        'Officer Disposition': 'SUSTAINED',
#        'Action Taken': 'COUNSELING',
#        'Body Cam': 'No'}]}]},
#   {'id': 4,
#    'content': [{'type': 'table',
#      'content': [{'Date': '3/18/2008',
#        'Number': '08-06',
#        'Investigator': 'Gallo, Joe',
#        'Date Assigned': 'missing',
#        'Racial': 'No',
#        'Category / Type': 'FORMAL',
#        'Location Of Occurrence': 'Not Stated',
#        'Disposition': 'SUSTAINED',
#        'Completed': 'missing',
#        'Recorded On Camera': 'No'},
#       {'Date': 'missing',
#        'Number': 'missing',
#        'Investigator': 'missing',
#        'Date Assigned': '4/17/2008',
#        'Racial': 'missing',
#        'Category / Type': 'Citizen',
#        'Location Of Occurrence': 'missing',
#        'Disposition': 'missing',
#        'Completed': '4/23/2008',
#        'Recorded On Camera': 'N/A'}]},
#     {'type': 'kv',
#      'content': [{'Complainant': 'missing'},
#       {'DOB': 'missing'},
#       {'Gender': 'MALE'},
#       {'Address': ', Champaign IL 61821'},
#       {'H Phone': 'missing'}]},
#     {'type': 'table',
#      'content': [{'Type Of Complaint': 'R-3B.1 Courtesy',
#        'Description': 'Discourteous Conduct',
#        'Complaint Disposition': 'NOT SUSTAINED'},
#       {'Type Of Complaint': 'R-3B.4 COURTESY',
#        'Description': 'Discourteous Conduct',
#        'Complaint Disposition': 'SUSTAINED'}]},
#     {'type': 'table',
#      'content': [{'Name': 'Kelly, Patrick M.',
#        'ID No.': '722-Ret',
#        'Rank': 'DETECTIVE',
#        'Division': 'Operations Supp',
#        'Officer Disposition': 'SUSTAINED',
#        'Action Taken': 'COUNSELING',
#        'Body Cam': 'No'}]}]},
#   {'id': 5,
#    'content': [{'type': 'table',
#      'content': [{'Date': 'missing',
#        'Number': 'missing',
#        'Investigator': 'missing',
#        'Date Assigned': '4/16/2008',
#        'Racial': 'missing',
#        'Category / Type': 'Citizen',
#        'Location Of Occurrence': 'missing',
#        'Disposition': 'missing',
#        'Completed': '5/1/2008',
#        'Recorded On Camera': 'N/A'}]},
#     {'type': 'kv',
#      'content': [{'Complainant': 'missing'},
#       {'DOB': 'missing'},
#       {'Gender': 'MALE'},
#       {'Address': 'Ct, Rantoul IL 61866'},
#       {'H Phone': '('}]},
#     {'type': 'table',
#      'content': [{'Type Of Complaint': 'R-5D Use of physical force',
#        'Description': 'Wrong Action by Employee',
#        'Complaint Disposition': 'UNFOUNDED'}]},
#     {'type': 'table',
#      'content': [{'Name': 'Lack, Aaron V.',
#        'ID No.': '920',
#        'Rank': 'SERGEANT',
#        'Division': 'Field Operations',
#        'Officer Disposition': 'UNFOUNDED',
#        'Action Taken': 'NONE',
#        'Body Cam': 'No'},
#       {'Name': 'MULTIPLE OFFICERS/EMPLOY',
#        'ID No.': 'missing',
#        'Rank': 'NOT STATED',
#        'Division': 'NOT ENTERED',
#        'Officer Disposition': 'UNFOUNDED',
#        'Action Taken': 'NONE',
#        'Body Cam': 'No'}]}]},
#   {'id': 6,
#    'content': [{'type': 'table',
#      'content': [{'Date': 'missing',
#        'Number': 'missing',
#        'Investigator': 'missing',
#        'Date Assigned': '4/16/2008',
#        'Racial': 'missing',
#        'Category / Type': 'Citizen',
#        'Location Of Occurrence': 'missing',
#        'Disposition': 'missing',
#        'Completed': '5/1/2008',
#        'Recorded On Camera': 'N/A'}]},
#     {'type': 'kv',
#      'content': [{'Complainant': 'missing'},
#       {'DOB': 'missing'},
#       {'Gender': 'FEMAL'},
#       {'Address': ', CHICAGO IL 60644-2803'},
#       {'H Phone': 'missing'}]},
#     {'type': 'table',
#      'content': [{'Type Of Complaint': 'R-5D Use of physical force',
#        'Description': 'Wrong Action by Employee',
#        'Complaint Disposition': 'UNFOUNDED'}]},
#     {'type': 'table',
#      'content': [{'Name': 'MULTIPLE OFFICERS/EMPLOY',
#        'ID No.': 'missing',
#        'Rank': 'NOT STATED',
#        'Division': 'NOT ENTERED',
#        'Officer Disposition': 'UNFOUNDED',
#        'Action Taken': 'NONE',
#        'Body Cam': 'No'}]}]},
#   {'id': 7,
#    'content': [{'type': 'table',
#      'content': [{'Date': 'missing',
#        'Number': 'missing',
#        'Investigator': 'missing',
#        'Date Assigned': '4/16/2008',
#        'Racial': 'missing',
#        'Category / Type': 'Citizen',
#        'Location Of Occurrence': 'missing',
#        'Disposition': 'missing',
#        'Completed': '5/1/2008',
#        'Recorded On Camera': 'N/A'}]},
#     {'type': 'kv',
#      'content': [{'Complainant': 'missing'},
#       {'DOB': 'missing'},
#       {'Gender': 'FEMAL'},
#       {'Address': ', Champaign IL 61820'},
#       {'H Phone': 'missing'}]},
#     {'type': 'table',
#      'content': [{'Type Of Complaint': 'R-5D Use of physical force',
#        'Description': 'Wrong Action by Employee',
#        'Complaint Disposition': 'EXONERATED'}]},
#     {'type': 'table',
#      'content': [{'Name': 'MULTIPLE OFFICERS/EMPLOY',
#        'ID No.': 'missing',
#        'Rank': 'NOT STATED',
#        'Division': 'NOT ENTERED',
#        'Officer Disposition': 'UNFOUNDED',
#        'Action Taken': 'NONE',
#        'Body Cam': 'No'}]}]},
#   {'id': 8,
#    'content': [{'type': 'table',
#      'content': [{'Date': 'missing',
#        'Number': 'missing',
#        'Investigator': 'missing',
#        'Date Assigned': '4/16/2008',
#        'Racial': 'missing',
#        'Category / Type': 'Citizen',
#        'Location Of Occurrence': 'missing',
#        'Disposition': 'missing',
#        'Completed': '5/1/2008',
#        'Recorded On Camera': 'N/A'}]},
#     {'type': 'kv',
#      'content': [{'Complainant': 'missing'},
#       {'DOB': 'missing'},
#       {'Gender': 'FEMAL'},
#       {'Address': ', Rantoul IL 61866'},
#       {'H Phone': 'missing'}]},
#     {'type': 'table',
#      'content': [{'Type Of Complaint': 'R-5D Use of physical force',
#        'Description': 'Wrong Action by Employee',
#        'Complaint Disposition': 'EXONERATED'}]},
#     {'type': 'table',
#      'content': [{'Name': 'MULTIPLE OFFICERS/EMPLOY',
#        'ID No.': 'missing',
#        'Rank': 'NOT STATED',
#        'Division': 'NOT ENTERED',
#        'Officer Disposition': 'UNFOUNDED',
#        'Action Taken': 'NONE',
#        'Body Cam': 'No'}]}]},
#   {'id': 9,
#    'content': [{'type': 'table',
#      'content': [{'Date': 'missing',
#        'Number': 'missing',
#        'Investigator': 'missing',
#        'Date Assigned': '4/10/2008',
#        'Racial': 'missing',
#        'Category / Type': 'Internal',
#        'Location Of Occurrence': 'missing',
#        'Disposition': 'missing',
#        'Completed': '5/10/2008',
#        'Recorded On Camera': 'N/A'}]},
#     {'type': 'kv',
#      'content': [{'Complainant': 'CPD'},
#       {'DOB': 'missing'},
#       {'Gender': 'missing'},
#       {'Address': 'NOT STATED ?? UNK'},
#       {'H Phone': 'missing'}]},
#     {'type': 'table',
#      'content': [{'Type Of Complaint': 'S-6 Pursuit Policy',
#        'Description': 'Wrong Action by Employee',
#        'Complaint Disposition': 'Not a complaint'}]},
#     {'type': 'table',
#      'content': [{'Name': 'MALONEY, J. BRIAN',
#        'ID No.': '942',
#        'Rank': 'OFFICER',
#        'Division': 'Field Operations',
#        'Officer Disposition': 'Not a complaint',
#        'Action Taken': 'NONE',
#        'Body Cam': 'No'}]}]},
#   {'id': 10,
#    'content': [{'type': 'table',
#      'content': [{'Date': 'missing',
#        'Number': 'missing',
#        'Investigator': 'missing',
#        'Date Assigned': '4/16/2008',
#        'Racial': 'missing',
#        'Category / Type': 'Citizen',
#        'Location Of Occurrence': 'missing',
#        'Disposition': 'missing',
#        'Completed': '5/14/2008',
#        'Recorded On Camera': 'N/A'}]},
#     {'type': 'kv',
#      'content': [{'Complainant': 'missing'},
#       {'DOB': 'missing'},
#       {'Gender': 'FEMAL'},
#       {'Address': ', Champaign IL 61821'},
#       {'H Phone': 'missing'}]},
#     {'type': 'table',
#      'content': [{'Type Of Complaint': 'R-5A3 OPERATIONS',
#        'Description': 'No Action by Employee',
#        'Complaint Disposition': 'Not a complaint'}]},
#     {'type': 'table',
#      'content': [{'Name': 'Sumption, R. Dustin',
#        'ID No.': '7108',
#        'Rank': 'RECRUIT OFFIC',
#        'Division': 'Field Operations',
#        'Officer Disposition': 'PENDING',
#        'Action Taken': 'NONE',
#        'Body Cam': 'No'}]}]},
#   {'id': 11,
#    'content': [{'type': 'table',
#      'content': [{'Date': 'missing',
#        'Number': 'missing',
#        'Investigator': 'missing',
#        'Date Assigned': '10/2/2008',
#        'Racial': 'missing',
#        'Category / Type': 'Internal',
#        'Location Of Occurrence': 'missing',
#        'Disposition': 'missing',
#        'Completed': '4/17/2009',
#        'Recorded On Camera': 'N/A'}]},
#     {'type': 'kv',
#      'content': [{'Complainant': 'missing'},
#       {'DOB': 'missing'},
#       {'Gender': 'FEMAL'},
#       {'Address': ', Loves Park IL 61130'},
#       {'H Phone': 'missing'}]},
#     {'type': 'table',
#      'content': [{'Type Of Complaint': 'R-1A2 CONDUCT GENERALLY',
#        'Description': 'Wrong Action by Employee',
#        'Complaint Disposition': 'Inquiry'}]},
#     {'type': 'table',
#      'content': [{'Name': 'No Officers Entered',
#        'ID No.': 'missing',
#        'Rank': 'Not Stated',
#        'Division': 'Not Stated',
#        'Officer Disposition': 'Not a complaint',
#        'Action Taken': 'Not Stated',
#        'Body Cam': 'No'}]}]},
#   {'id': 12,
#    'content': [{'type': 'table',
#      'content': [{'Date': 'missing',
#        'Number': 'missing',
#        'Investigator': 'missing',
#        'Date Assigned': '6/5/2008',
#        'Racial': 'missing',
#        'Category / Type': 'Citizen',
#        'Location Of Occurrence': 'missing',
#        'Disposition': 'missing',
#        'Completed': '7/2/2008',
#        'Recorded On Camera': 'N/A'}]},
#     {'type': 'kv',
#      'content': [{'Complainant': 'missing'},
#       {'DOB': 'missing'},
#       {'Gender': 'MALE'},
#       {'Address': ', Champaign IL 61820'},
#       {'H Phone': 'missing'}]},
#     {'type': 'table',
#      'content': [{'Type Of Complaint': 'R-3B.4 COURTESY',
#        'Description': 'Discourteous Conduct',
#        'Complaint Disposition': 'SUSTAINED'},
#       {'Type Of Complaint': 'R-5D Use of physical force',
#        'Description': 'Wrong Action by Employee',
#        'Complaint Disposition': 'EXONERATED'}]},
#     {'type': 'table', 'content': []}]},
#   {'id': 13,
#    'content': [{'type': 'table',
#      'content': [{'Date': '5/26/2008',
#        'Number': '08-07',
#        'Investigator': 'Swan, Scott',
#        'Date Assigned': 'missing',
#        'Racial': 'No',
#        'Category / Type': 'Inquiry',
#        'Location Of Occurrence': 'Not Stated',
#        'Disposition': 'Inquiry',
#        'Completed': 'missing',
#        'Recorded On Camera': 'No'},
#       {'Date': 'missing',
#        'Number': 'missing',
#        'Investigator': 'missing',
#        'Date Assigned': '6/2/2008',
#        'Racial': 'missing',
#        'Category / Type': 'Citizen',
#        'Location Of Occurrence': 'missing',
#        'Disposition': 'missing',
#        'Completed': '6/11/2008',
#        'Recorded On Camera': 'N/A'}]},
#     {'type': 'kv',
#      'content': [{'Complainant': 'missing'},
#       {'DOB': 'missing'},
#       {'Gender': 'FEMAL'},
#       {'Address': 'Champaign IL 61821'},
#       {'H Phone': 'missing'}]},
#     {'type': 'table',
#      'content': [{'Type Of Complaint': 'R-3B COURTESY',
#        'Description': 'Discourteous Conduct',
#        'Complaint Disposition': 'Inquiry'}]},
#     {'type': 'table',
#      'content': [{'Name': 'Olmstead, Kevin A.',
#        'ID No.': '7901',
#        'Rank': 'RECRUIT OFFIC',
#        'Division': 'Field Operations',
#        'Officer Disposition': 'Inquiry',
#        'Action Taken': 'NONE',
#        'Body Cam': 'No'}]}]},
#   {'id': 14,
#    'content': [{'type': 'table',
#      'content': [{'Date': 'missing',
#        'Number': 'missing',
#        'Investigator': 'missing',
#        'Date Assigned': '6/5/2008',
#        'Racial': 'missing',
#        'Category / Type': 'Citizen',
#        'Location Of Occurrence': 'missing',
#        'Disposition': 'missing',
#        'Completed': '10/2/2008',
#        'Recorded On Camera': 'N/A'}]},
#     {'type': 'kv',
#      'content': [{'Complainant': 'missing'},
#       {'DOB': 'missing'},
#       {'Gender': 'MALE'},
#       {'Address': ', Champaign IL 61821'},
#       {'H Phone': 'missing'}]},
#     {'type': 'table',
#      'content': [{'Type Of Complaint': 'R-5B ARREST, SEARCH AND SEIZURE',
#        'Description': 'Wrong Action by Employee',
#        'Complaint Disposition': 'EXONERATED'},
#       {'Type Of Complaint': 'R-5D Use of physical force',
#        'Description': 'Wrong Action by Employee',
#        'Complaint Disposition': 'EXONERATED'}]},
#     {'type': 'table',
#      'content': [{'Name': 'Bowersock, Jamie',
#        'ID No.': '705-MED',
#        'Rank': 'OFFICER',
#        'Division': 'Field Operations',
#        'Officer Disposition': 'EXONERATED',
#        'Action Taken': 'NONE',
#        'Body Cam': 'No'},
#       {'Name': 'Mitchell, Rodney S.',
#        'ID No.': '717RES',
#        'Rank': 'OFFICER',
#        'Division': 'Field Operations',
#        'Officer Disposition': 'EXONERATED',
#        'Action Taken': 'NONE',
#        'Body Cam': 'No'}]}]},
#   {'id': 15,
#    'content': [{'type': 'table',
#      'content': [{'Date': 'missing',
#        'Number': 'missing',
#        'Investigator': 'missing',
#        'Date Assigned': '6/11/2008',
#        'Racial': 'missing',
#        'Category / Type': 'Citizen',
#        'Location Of Occurrence': 'missing',
#        'Disposition': 'missing',
#        'Completed': '6/26/2008',
#        'Recorded On Camera': 'N/A'}]},
#     {'type': 'kv',
#      'content': [{'Complainant': 'missing'},
#       {'DOB': 'missing'},
#       {'Gender': 'MALE'},
#       {'Address': ', Champaign IL 61821'},
#       {'H Phone': 'missing'}]},
#     {'type': 'table',
#      'content': [{'Type Of Complaint': 'R-5D Use of physical force',
#        'Description': 'Wrong Action by Employee',
#        'Complaint Disposition': 'NOT SUSTAINED'}]},
#     {'type': 'table',
#      'content': [{'Name': 'Mclearin, David M.',
#        'ID No.': '7110',
#        'Rank': 'RECRUIT OFFIC',
#        'Division': 'Field Operations',
#        'Officer Disposition': 'NOT SUSTAINED',
#        'Action Taken': 'NONE',
#        'Body Cam': 'No'}]}]},
#   {'id': 16,
#    'content': [{'type': 'table',
#      'content': [{'Date': 'missing',
#        'Number': 'missing',
#        'Investigator': 'missing',
#        'Date Assigned': '7/9/2008',
#        'Racial': 'missing',
#        'Category / Type': 'Citizen',
#        'Location Of Occurrence': 'missing',
#        'Disposition': 'missing',
#        'Completed': '7/31/2008',
#        'Recorded On Camera': 'N/A'}]},
#     {'type': 'kv',
#      'content': [{'Complainant': 'missing'},
#       {'DOB': 'missing'},
#       {'Gender': 'FEMAL'},
#       {'Address': ', Champaign IL 61821'},
#       {'H Phone': 'missing'}]},
#     {'type': 'table',
#      'content': [{'Type Of Complaint': 'R-5D Use of physical force',
#        'Description': 'Wrong Action by Employee',
#        'Complaint Disposition': 'Inquiry'}]},
#     {'type': 'table',
#      'content': [{'Name': 'Prosser, Justin',
#        'ID No.': '7104',
#        'Rank': 'OFFICER',
#        'Division': 'Field Operations',
#        'Officer Disposition': 'Inquiry',
#        'Action Taken': 'NONE',
#        'Body Cam': 'No'}]}]},
#   {'id': 17,
#    'content': [{'type': 'table',
#      'content': [{'Date': 'missing',
#        'Number': 'missing',
#        'Investigator': 'missing',
#        'Date Assigned': '7/11/2008',
#        'Racial': 'missing',
#        'Category / Type': 'Citizen',
#        'Location Of Occurrence': 'missing',
#        'Disposition': 'missing',
#        'Completed': '10/6/2008',
#        'Recorded On Camera': 'N/A'}]},
#     {'type': 'kv',
#      'content': [{'Complainant': 'missing'},
#       {'DOB': 'missing'},
#       {'Gender': 'FEMAL'},
#       {'Address': ', Champaign IL 61820'},
#       {'H Phone': '('}]},
#     {'type': 'table',
#      'content': [{'Type Of Complaint': 'R-5C2 PERSONS IN CUSTODY',
#        'Description': 'Wrong Action by Employee',
#        'Complaint Disposition': 'UNFOUNDED'},
#       {'Type Of Complaint': 'R-5D Use of physical force',
#        'Description': 'Wrong Action by Employee',
#        'Complaint Disposition': 'UNFOUNDED'}]},
#     {'type': 'table',
#      'content': [{'Name': 'Briggs, Mark D.',
#        'ID No.': '785RESI',
#        'Rank': 'Senior OFFICER',
#        'Division': 'Field Operations',
#        'Officer Disposition': 'UNFOUNDED',
#        'Action Taken': 'NONE',
#        'Body Cam': 'No'},
#       {'Name': 'Young, Von D.III',
#        'ID No.': '719',
#        'Rank': 'Senior',
#        'Division': 'Field Operations',
#        'Officer Disposition': 'UNFOUNDED',
#        'Action Taken': 'NONE',
#        'Body Cam': 'No'}]}]},
#   {'id': 18,
#    'content': [{'type': 'table',
#      'content': [{'Date': 'missing',
#        'Number': 'missing',
#        'Investigator': 'missing',
#        'Date Assigned': '7/16/2008',
#        'Racial': 'missing',
#        'Category / Type': 'Citizen',
#        'Location Of Occurrence': 'missing',
#        'Disposition': 'missing',
#        'Completed': '8/28/2008',
#        'Recorded On Camera': 'N/A'}]},
#     {'type': 'kv',
#      'content': [{'Complainant': 'missing'},
#       {'DOB': 'missing'},
#       {'Gender': 'MALE'},
#       {'Address': ', Champaign IL 61820'},
#       {'H Phone': '('}]},
#     {'type': 'table',
#      'content': [{'Type Of Complaint': 'R-3B.2 Courtesy',
#        'Description': 'Discourteous Conduct',
#        'Complaint Disposition': 'UNFOUNDED'},
#       {'Type Of Complaint': 'R-5D Use of physical force',
#        'Description': 'Wrong Action by Employee',
#        'Complaint Disposition': 'UNFOUNDED'}]},
#     {'type': 'table',
#      'content': [{'Name': 'Bowersock, Jamie',
#        'ID No.': '705-MED',
#        'Rank': 'OFFICER',
#        'Division': 'Field Operations',
#        'Officer Disposition': 'UNFOUNDED',
#        'Action Taken': 'NONE',
#        'Body Cam': 'No'}]}]},
#   {'id': 19,
#    'content': [{'type': 'table',
#      'content': [{'Date': 'missing',
#        'Number': 'missing',
#        'Investigator': 'missing',
#        'Date Assigned': '7/23/2008',
#        'Racial': 'missing',
#        'Category / Type': 'Citizen',
#        'Location Of Occurrence': 'missing',
#        'Disposition': 'missing',
#        'Completed': '8/18/2008',
#        'Recorded On Camera': 'N/A'}]},
#     {'type': 'kv',
#      'content': [{'Complainant': 'missing'},
#       {'DOB': 'missing'},
#       {'Gender': 'MALE'},
#       {'Address': ', Champaign IL 61820'},
#       {'H Phone': 'missing'}]},
#     {'type': 'table',
#      'content': [{'Type Of Complaint': 'R-3B.3 Courtesy',
#        'Description': 'Wrong Action by Employee',
#        'Complaint Disposition': 'UNFOUNDED'}]},
#     {'type': 'table',
#      'content': [{'Name': 'Olmstead, Kevin A.',
#        'ID No.': '7901',
#        'Rank': 'OFFICER',
#        'Division': 'Field Operations',
#        'Officer Disposition': 'UNFOUNDED',
#        'Action Taken': 'NONE',
#        'Body Cam': 'No'}]}]},
#   {'id': 20,
#    'content': [{'type': 'table',
#      'content': [{'Date': '7/29/2008',
#        'Number': '08-15',
#        'Investigator': 'Swenson, Jon',
#        'Date Assigned': 'missing',
#        'Racial': 'No',
#        'Category / Type': 'Formal',
#        'Location Of Occurrence': 'Not Stated',
#        'Disposition': 'SUSTAINED',
#        'Completed': 'missing',
#        'Recorded On Camera': 'No'},
#       {'Date': 'missing',
#        'Number': 'missing',
#        'Investigator': 'missing',
#        'Date Assigned': '8/21/2008',
#        'Racial': 'missing',
#        'Category / Type': 'Citizen',
#        'Location Of Occurrence': 'missing',
#        'Disposition': 'missing',
#        'Completed': '9/26/2008',
#        'Recorded On Camera': 'N/A'}]},
#     {'type': 'kv',
#      'content': [{'Complainant': 'missing'},
#       {'DOB': 'missing'},
#       {'Gender': 'MALE'},
#       {'Address': ', Urbana IL 61802'},
#       {'H Phone': 'missing'}]},
#     {'type': 'table',
#      'content': [{'Type Of Complaint': 'R-5A3 OPERATIONS',
#        'Description': 'Wrong Action by Employee',
#        'Complaint Disposition': 'SUSTAINED'},
#       {'Type Of Complaint': 'R-5B ARREST, SEARCH AND SEIZURE',
#        'Description': 'Wrong Action by Employee',
#        'Complaint Disposition': 'UNFOUNDED'},
#       {'Type Of Complaint': 'R-5B ARREST, SEARCH AND SEIZURE',
#        'Description': 'Wrong Action by Employee',
#        'Complaint Disposition': 'UNFOUNDED'},
#       {'Type Of Complaint': 'R-5B ARREST, SEARCH AND SEIZURE',
#        'Description': 'Wrong Action by Employee',
#        'Complaint Disposition': 'UNFOUNDED'}]},
#     {'type': 'table',
#      'content': [{'Name': 'MULTIPLE OFFICERS/EMPLOY',
#        'ID No.': 'missing',
#        'Rank': 'NOT STATED',
#        'Division': 'NOT ENTERED',
#        'Officer Disposition': 'UNFOUNDED',
#        'Action Taken': 'NONE',
#        'Body Cam': 'No'}]}]},
#   {'id': 21,
#    'content': [{'type': 'table',
#      'content': [{'Date': 'missing',
#        'Number': 'missing',
#        'Investigator': 'missing',
#        'Date Assigned': '9/2/2008',
#        'Racial': 'missing',
#        'Category / Type': 'Citizen',
#        'Location Of Occurrence': 'missing',
#        'Disposition': 'missing',
#        'Completed': '10/9/2008',
#        'Recorded On Camera': 'N/A'}]},
#     {'type': 'kv',
#      'content': [{'Complainant': 'missing'},
#       {'DOB': 'missing'},
#       {'Gender': 'MALE'},
#       {'Address': ', Champaign IL 61821'},
#       {'H Phone': 'missing'}]},
#     {'type': 'table',
#      'content': [{'Type Of Complaint': 'R-5A3 OPERATIONS',
#        'Description': 'Wrong Action by Employee',
#        'Complaint Disposition': 'NOT SUSTAINED'},
#       {'Type Of Complaint': 'R-5A3 OPERATIONS',
#        'Description': 'No Action by Employee',
#        'Complaint Disposition': 'EXONERATED'},
#       {'Type Of Complaint': 'R-5C2 PERSONS IN CUSTODY',
#        'Description': 'No Action by Employee',
#        'Complaint Disposition': 'EXONERATED'},
#       {'Type Of Complaint': 'R-5D Use of physical force',
#        'Description': 'Wrong Action by Employee',
#        'Complaint Disposition': 'UNFOUNDED'}]},
#     {'type': 'table',
#      'content': [{'Name': 'Talbott, Michael A.',
#        'ID No.': '7105',
#        'Rank': 'OFFICER',
#        'Division': 'Field Operations',
#        'Officer Disposition': 'EXONERATED',
#        'Action Taken': 'NONE',
#        'Body Cam': 'No'}]}]},
#   {'id': 22,
#    'content': [{'type': 'table',
#      'content': [{'Date': '8/18/2008',
#        'Number': '08-II03',
#        'Investigator': 'Gallo, Joe',
#        'Date Assigned': 'missing',
#        'Racial': 'No',
#        'Category / Type': 'Formal',
#        'Location Of Occurrence': 'Not Stated',
#        'Disposition': 'SUSTAINED',
#        'Completed': 'missing',
#        'Recorded On Camera': 'No'},
#       {'Date': 'missing',
#        'Number': 'missing',
#        'Investigator': 'missing',
#        'Date Assigned': '8/18/2008',
#        'Racial': 'missing',
#        'Category / Type': 'Internal',
#        'Location Of Occurrence': 'missing',
#        'Disposition': 'missing',
#        'Completed': '8/28/2008',
#        'Recorded On Camera': 'N/A'}]},
#     {'type': 'kv',
#      'content': [{'Complainant': 'NOT STATED'},
#       {'DOB': 'missing'},
#       {'Gender': 'missing'},
#       {'Address': 'NOT STATED ?? UNK'},
#       {'H Phone': 'missing'}]},
#     {'type': 'table',
#      'content': [{'Type Of Complaint': 'R-4E Authorized Persons in Vehicle',
#        'Description': 'Wrong Action by Employee',
#        'Complaint Disposition': 'SUSTAINED'}]},
#     {'type': 'table', 'content': []}]},
#   {'id': 23,
#    'content': [{'type': 'table',
#      'content': [{'Date': '8/30/2008',
#        'Number': '08-17',
#        'Investigator': 'Yohnka, Brad',
#        'Date Assigned': 'missing',
#        'Racial': 'No',
#        'Category / Type': 'Formal',
#        'Location Of Occurrence': 'Not Stated',
#        'Disposition': 'SUSTAINED',
#        'Completed': 'missing',
#        'Recorded On Camera': 'No'},
#       {'Date': 'missing',
#        'Number': 'missing',
#        'Investigator': 'missing',
#        'Date Assigned': '9/2/2008',
#        'Racial': 'missing',
#        'Category / Type': 'Citizen',
#        'Location Of Occurrence': 'missing',
#        'Disposition': 'missing',
#        'Completed': '10/29/2008',
#        'Recorded On Camera': 'N/A'}]},
#     {'type': 'kv',
#      'content': [{'Complainant': 'missing'},
#       {'DOB': 'missing'},
#       {'Gender': 'MALE'},
#       {'Address': 'Champaign IL 61820'},
#       {'H Phone': 'missing'}]},
#     {'type': 'table',
#      'content': [{'Type Of Complaint': 'R-3C PROVIDING NAME AND BADGE NUMBER',
#        'Description': 'Wrong Action by Employee',
#        'Complaint Disposition': 'SUSTAINED'},
#       {'Type Of Complaint': 'R-5D Use of physical force',
#        'Description': 'Wrong Action by Employee',
#        'Complaint Disposition': 'UNFOUNDED'}]},
#     {'type': 'table',
#      'content': [{'Name': 'Ahsell, Brian',
#        'ID No.': '714-',
#        'Rank': 'OFFICER',
#        'Division': 'Field Operations',
#        'Officer Disposition': 'SUSTAINED',
#        'Action Taken': 'COUNSELING',
#        'Body Cam': 'No'},
#       {'Name': 'missing',
#        'ID No.': 'Resig',
#        'Rank': 'missing',
#        'Division': 'missing',
#        'Officer Disposition': 'missing',
#        'Action Taken': 'missing',
#        'Body Cam': 'missing'}]}]},
#   {'id': 24,
#    'content': [{'type': 'table',
#      'content': [{'Date': 'missing',
#        'Number': 'missing',
#        'Investigator': 'missing',
#        'Date Assigned': '9/3/2008',
#        'Racial': 'missing',
#        'Category / Type': 'Internal',
#        'Location Of Occurrence': 'missing',
#        'Disposition': 'missing',
#        'Completed': '9/4/2008',
#        'Recorded On Camera': 'N/A'}]},
#     {'type': 'kv',
#      'content': [{'Complainant': 'missing'},
#       {'DOB': 'missing'},
#       {'Gender': 'MALE'},
#       {'Address': 'Central HS, NOT STATED ?? UNK'},
#       {'H Phone': 'missing'}]},
#     {'type': 'table',
#      'content': [{'Type Of Complaint': 'R-1A CONDUCT GENERALLY',
#        'Description': 'Wrong Action by Employee',
#        'Complaint Disposition': 'UNFOUNDED'}]},
#     {'type': 'table',
#      'content': [{'Name': 'Thomas, Brandon J.',
#        'ID No.': '904',
#        'Rank': 'Senior',
#        'Division': 'Field Operations',
#        'Officer Disposition': 'UNFOUNDED',
#        'Action Taken': 'NONE',
#        'Body Cam': 'No'}]}]},
#   {'id': 25,
#    'content': [{'type': 'table',
#      'content': [{'Date': '9/7/2008',
#        'Number': '08-20',
#        'Investigator': 'Swan, Scott',
#        'Date Assigned': 'missing',
#        'Racial': 'No',
#        'Category / Type': 'Formal',
#        'Location Of Occurrence': 'Not Stated',
#        'Disposition': 'SUSTAINED',
#        'Completed': 'missing',
#        'Recorded On Camera': 'No'},
#       {'Date': 'missing',
#        'Number': 'missing',
#        'Investigator': 'missing',
#        'Date Assigned': '9/15/2008',
#        'Racial': 'missing',
#        'Category / Type': 'Citizen',
#        'Location Of Occurrence': 'missing',
#        'Disposition': 'missing',
#        'Completed': '10/8/2008',
#        'Recorded On Camera': 'N/A'}]},
#     {'type': 'kv',
#      'content': [{'Complainant': 'missing'},
#       {'DOB': 'missing'},
#       {'Gender': 'FEMAL'},
#       {'Address': ', Champaign IL 61821'},
#       {'H Phone': 'missing'}]},
#     {'type': 'table',
#      'content': [{'Type Of Complaint': 'R-3B COURTESY',
#        'Description': 'Discourteous Conduct',
#        'Complaint Disposition': 'NOT SUSTAINED'},
#       {'Type Of Complaint': 'R-3C PROVIDING NAME AND BADGE NUMBER',
#        'Description': 'Wrong Action by Employee',
#        'Complaint Disposition': 'SUSTAINED'},
#       {'Type Of Complaint': 'R-5B ARREST, SEARCH AND SEIZURE',
#        'Description': 'Wrong Action by Employee',
#        'Complaint Disposition': 'NOT SUSTAINED'}]},
#     {'type': 'table',
#      'content': [{'Name': 'Epling, Nate',
#        'ID No.': '765',
#        'Rank': 'RECRUIT OFFIC',
#        'Division': 'Field Operations',
#        'Officer Disposition': 'SUSTAINED',
#        'Action Taken': 'COUNSELING',
#        'Body Cam': 'No'},
#       {'Name': 'Olmstead, Kevin A.',
#        'ID No.': '7901',
#        'Rank': 'OFFICER',
#        'Division': 'Field Operations',
#        'Officer Disposition': 'SUSTAINED',
#        'Action Taken': 'COUNSELING',
#        'Body Cam': 'No'}]}]},
#   {'id': 26,
#    'content': [{'type': 'table',
#      'content': [{'Date': 'missing',
#        'Number': 'missing',
#        'Investigator': 'missing',
#        'Date Assigned': '10/1/2008',
#        'Racial': 'missing',
#        'Category / Type': 'Citizen',
#        'Location Of Occurrence': 'missing',
#        'Disposition': 'missing',
#        'Completed': '10/2/2008',
#        'Recorded On Camera': 'N/A'}]},
#     {'type': 'kv',
#      'content': [{'Complainant': 'missing'},
#       {'DOB': 'missing'},
#       {'Gender': 'MALE'},
#       {'Address': '1302 W Beslin, Urbana IL 61801'},
#       {'H Phone': 'missing'}]},
#     {'type': 'table',
#      'content': [{'Type Of Complaint': 'R-5D Use of physical force',
#        'Description': 'Wrong Action by Employee',
#        'Complaint Disposition': 'UNFOUNDED'}]},
#     {'type': 'table',
#      'content': [{'Name': 'Clinton, Justus R.',
#        'ID No.': '713-',
#        'Rank': 'OFFICER',
#        'Division': 'Field Operations',
#        'Officer Disposition': 'UNFOUNDED',
#        'Action Taken': 'NONE',
#        'Body Cam': 'No'},
#       {'Name': 'missing',
#        'ID No.': 'Resig',
#        'Rank': 'missing',
#        'Division': 'missing',
#        'Officer Disposition': 'missing',
#        'Action Taken': 'missing',
#        'Body Cam': 'missing'}]}]},
#   {'id': 27,
#    'content': [{'type': 'table',
#      'content': [{'Date': 'missing',
#        'Number': 'missing',
#        'Investigator': 'missing',
#        'Date Assigned': '9/30/2008',
#        'Racial': 'missing',
#        'Category / Type': 'Citizen',
#        'Location Of Occurrence': 'missing',
#        'Disposition': 'missing',
#        'Completed': '10/30/2008',
#        'Recorded On Camera': 'N/A'}]},
#     {'type': 'kv',
#      'content': [{'Complainant': 'missing'},
#       {'DOB': 'missing'},
#       {'Gender': 'MALE'},
#       {'Address': ', Thomasboro IL 61878'},
#       {'H Phone': 'missing'}]},
#     {'type': 'table',
#      'content': [{'Type Of Complaint': 'R-5D Use of physical force',
#        'Description': 'Wrong Action by Employee',
#        'Complaint Disposition': 'UNFOUNDED'}]},
#     {'type': 'table',
#      'content': [{'Name': 'Aikman, Chris',
#        'ID No.': '712',
#        'Rank': 'OFFICER',
#        'Division': 'Field Operations',
#        'Officer Disposition': 'UNFOUNDED',
#        'Action Taken': 'NONE',
#        'Body Cam': 'No'}]}]},
#   {'id': 28,
#    'content': [{'type': 'table',
#      'content': [{'Date': '10/16/2008',
#        'Number': '08-II06',
#        'Investigator': 'Nearing, Holly',
#        'Date Assigned': 'missing',
#        'Racial': 'No',
#        'Category / Type': 'Inquiry',
#        'Location Of Occurrence': 'Not Stated',
#        'Disposition': 'SUSTAINED',
#        'Completed': 'missing',
#        'Recorded On Camera': 'No'},
#       {'Date': 'missing',
#        'Number': 'missing',
#        'Investigator': 'missing',
#        'Date Assigned': '10/30/2008',
#        'Racial': 'missing',
#        'Category / Type': 'Internal',
#        'Location Of Occurrence': 'missing',
#        'Disposition': 'missing',
#        'Completed': '11/5/2008',
#        'Recorded On Camera': 'N/A'}]},
#     {'type': 'kv',
#      'content': [{'Complainant': 'NOT STATED'},
#       {'DOB': 'missing'},
#       {'Gender': 'missing'},
#       {'Address': 'NOT STATED ?? UNK'},
#       {'H Phone': 'missing'}]},
#     {'type': 'table',
#      'content': [{'Type Of Complaint': 'R-7F POLITICAL UTILIZATION OF OFFICIAL POSITION',
#        'Description': 'POLICY ISSUE',
#        'Complaint Disposition': 'SUSTAINED'}]},
#     {'type': 'table',
#      'content': [{'Name': 'Kelly, Patrick M.',
#        'ID No.': '722-Ret',
#        'Rank': 'DETECTIVE',
#        'Division': 'Operations Supp',
#        'Officer Disposition': 'SUSTAINED',
#        'Action Taken': 'COUNSELING',
#        'Body Cam': 'No'}]}]},
#   {'id': 29,
#    'content': [{'type': 'table',
#      'content': [{'Date': '10/29/2008',
#        'Number': '08-II05',
#        'Investigator': 'Nearing, Holly',
#        'Date Assigned': 'missing',
#        'Racial': 'No',
#        'Category / Type': 'Formal',
#        'Location Of Occurrence': 'Not Stated',
#        'Disposition': 'SUSTAINED',
#        'Completed': 'missing',
#        'Recorded On Camera': 'No'},
#       {'Date': 'missing',
#        'Number': 'missing',
#        'Investigator': 'missing',
#        'Date Assigned': '10/29/2008',
#        'Racial': 'missing',
#        'Category / Type': 'Internal',
#        'Location Of Occurrence': 'missing',
#        'Disposition': 'missing',
#        'Completed': '11/7/2008',
#        'Recorded On Camera': 'N/A'}]},
#     {'type': 'kv',
#      'content': [{'Complainant': 'NOT STATED'},
#       {'DOB': 'missing'},
#       {'Gender': 'missing'},
#       {'Address': 'NOT STATED ?? UNK'},
#       {'H Phone': 'missing'}]},
#     {'type': 'table',
#      'content': [{'Type Of Complaint': 'R-1A1 CONDUCT GENERALLY',
#        'Description': 'POLICY ISSUE',
#        'Complaint Disposition': 'SUSTAINED'}]},
#     {'type': 'table',
#      'content': [{'Name': 'KRIPPEL, JACOB',
#        'ID No.': '743TER',
#        'Rank': 'RECRUIT OFFIC',
#        'Division': 'Field Operations',
#        'Officer Disposition': 'SUSTAINED',
#        'Action Taken': 'TERMINATION',
#        'Body Cam': 'No'}]}]},
#   {'id': 30,
#    'content': [{'type': 'table',
#      'content': [{'Date': 'missing',
#        'Number': 'missing',
#        'Investigator': 'missing',
#        'Date Assigned': '11/4/2008',
#        'Racial': 'missing',
#        'Category / Type': 'Citizen',
#        'Location Of Occurrence': 'missing',
#        'Disposition': 'missing',
#        'Completed': '12/2/2008',
#        'Recorded On Camera': 'N/A'}]},
#     {'type': 'kv',
#      'content': [{'Complainant': 'missing'},
#       {'DOB': 'missing'},
#       {'Gender': 'FEMAL'},
#       {'Address': ', Champaign IL 61820'},
#       {'H Phone': 'missing'}]},
#     {'type': 'table',
#      'content': [{'Type Of Complaint': 'R-3B.2 Courtesy',
#        'Description': 'Discourteous Conduct',
#        'Complaint Disposition': 'UNFOUNDED'},
#       {'Type Of Complaint': 'R-5A3 OPERATIONS',
#        'Description': 'Wrong Action by Employee',
#        'Complaint Disposition': 'UNFOUNDED'}]},
#     {'type': 'table',
#      'content': [{'Name': 'Ferguson, Alison R.',
#        'ID No.': '792RETI',
#        'Rank': 'OFFICER',
#        'Division': 'Field Operations',
#        'Officer Disposition': 'UNFOUNDED',
#        'Action Taken': 'NONE',
#        'Body Cam': 'No'}]}]},
#   {'id': 31,
#    'content': [{'type': 'table',
#      'content': [{'Date': '11/29/2008',
#        'Number': '08-II07',
#        'Investigator': 'Nearing, Holly',
#        'Date Assigned': 'missing',
#        'Racial': 'No',
#        'Category / Type': 'Formal',
#        'Location Of Occurrence': 'Not Stated',
#        'Disposition': 'SUSTAINED',
#        'Completed': 'missing',
#        'Recorded On Camera': 'No'},
#       {'Date': 'missing',
#        'Number': 'missing',
#        'Investigator': 'missing',
#        'Date Assigned': '11/29/2008',
#        'Racial': 'missing',
#        'Category / Type': 'Internal',
#        'Location Of Occurrence': 'missing',
#        'Disposition': 'missing',
#        'Completed': '1/6/2009',
#        'Recorded On Camera': 'N/A'}]},
#     {'type': 'kv',
#      'content': [{'Complainant': 'CPD'},
#       {'DOB': 'missing'},
#       {'Gender': 'missing'},
#       {'Address': 'NOT STATED ?? UNK'},
#       {'H Phone': 'missing'}]},
#     {'type': 'table',
#      'content': [{'Type Of Complaint': 'R-1A CONDUCT GENERALLY',
#        'Description': 'POLICY ISSUE',
#        'Complaint Disposition': 'SUSTAINED'},
#       {'Type Of Complaint': 'R-1D DEVOTING FULL TIME ATTENTION TO DUTY',
#        'Description': 'POLICY ISSUE',
#        'Complaint Disposition': 'NOT SUSTAINED'},
#       {'Type Of Complaint': 'R-4A USE OF PROPERTY GENERALLY',
#        'Description': 'POLICY ISSUE',
#        'Complaint Disposition': 'SUSTAINED'},
#       {'Type Of Complaint': 'R-4D IMPROPER USE OF VEHICLE',
#        'Description': 'POLICY ISSUE',
#        'Complaint Disposition': 'SUSTAINED'}]},
#     {'type': 'table', 'content': []}]},
#   {'id': 32,
#    'content': [{'type': 'table',
#      'content': [{'Date': '12/6/2008',
#        'Number': '08-22',
#        'Investigator': 'Yohnka, Brad',
#        'Date Assigned': 'missing',
#        'Racial': 'No',
#        'Category / Type': 'Formal',
#        'Location Of Occurrence': 'Not Stated',
#        'Disposition': 'SUSTAINED',
#        'Completed': 'missing',
#        'Recorded On Camera': 'No'},
#       {'Date': 'missing',
#        'Number': 'missing',
#        'Investigator': 'missing',
#        'Date Assigned': '12/15/2008',
#        'Racial': 'missing',
#        'Category / Type': 'Citizen',
#        'Location Of Occurrence': 'missing',
#        'Disposition': 'missing',
#        'Completed': '12/17/2008',
#        'Recorded On Camera': 'N/A'}]},
#     {'type': 'kv',
#      'content': [{'Complainant': 'missing'},
#       {'DOB': 'missing'},
#       {'Gender': 'FEMAL'},
#       {'Address': '1001 Oak Creek circle, Mahomet IL 61853'},
#       {'H Phone': 'missing'}]},
#     {'type': 'table',
#      'content': [{'Type Of Complaint': 'R-1A3 POOR PERFORMANCE',
#        'Description': 'No Action by Employee',
#        'Complaint Disposition': 'SUSTAINED'},
#       {'Type Of Complaint': 'R-3B.2 Courtesy',
#        'Description': 'Discourteous Conduct',
#        'Complaint Disposition': 'SUSTAINED'}]},
#     {'type': 'table',
#      'content': [{'Name': 'missing',
#        'ID No.': 'Retire',
#        'Rank': 'missing',
#        'Division': 'missing',
#        'Officer Disposition': 'missing',
#        'Action Taken': 'missing',
#        'Body Cam': 'missing'}]}]},
#   {'id': 33,
#    'content': [{'type': 'table',
#      'content': [{'Date': 'missing',
#        'Number': 'missing',
#        'Investigator': 'missing',
#        'Date Assigned': '12/20/2008',
#        'Racial': 'missing',
#        'Category / Type': 'Citizen',
#        'Location Of Occurrence': 'missing',
#        'Disposition': 'missing',
#        'Completed': '1/20/2009',
#        'Recorded On Camera': 'N/A'}]},
#     {'type': 'kv',
#      'content': [{'Complainant': 'missing'},
#       {'DOB': 'missing'},
#       {'Gender': 'MALE'},
#       {'Address': '609 W. Washington, Urbana IL 61801'},
#       {'H Phone': 'missing'}]},
#     {'type': 'table',
#      'content': [{'Type Of Complaint': 'R-5D Use of physical force',
#        'Description': 'Wrong Action by Employee',
#        'Complaint Disposition': 'UNFOUNDED'}]},
#     {'type': 'table',
#      'content': [{'Name': 'Aikman, Chris',
#        'ID No.': '712',
#        'Rank': 'OFFICER',
#        'Division': 'Field Operations',
#        'Officer Disposition': 'UNFOUNDED',
#        'Action Taken': 'NONE',
#        'Body Cam': 'No'},
#       {'Name': 'Lack, Aaron V.',
#        'ID No.': '920',
#        'Rank': 'SERGEANT',
#        'Division': 'Field Operations',
#        'Officer Disposition': 'UNFOUNDED',
#        'Action Taken': 'NONE',
#        'Body Cam': 'No'}]}]},
#   {'id': 34,
#    'content': [{'type': 'table',
#      'content': [{'Date': 'missing',
#        'Number': 'missing',
#        'Investigator': 'missing',
#        'Date Assigned': '1/8/2009',
#        'Racial': 'missing',
#        'Category / Type': 'Citizen',
#        'Location Of Occurrence': 'missing',
# ...
#       {'Address': 'Champaign IL 61820'},
#       {'H Phone': 'missing'}]},
#     {'type': 'table',
#      'content': [{'Type Of Complaint': 'R-3B COURTESY',
#        'Description': 'Discourteous Conduct',
#        'Complaint Disposition': 'NOT SUSTAINED'}]},
#     {'type': 'table',
#      'content': [{'Name': 'reddy, ganesh k.',
#        'ID No.': '771',
#        'Rank': 'Senior',
#        'Division': 'Field Operations',
#        'Officer Disposition': 'NOT SUSTAINED',
#        'Action Taken': 'Pending',
#        'Body Cam': 'No'}]}]},
#   {'id': 258,
#    'content': [{'type': 'table',
#      'content': [{'Date': 'missing',
#        'Number': 'missing',
#        'Investigator': 'missing',
#        'Date Assigned': '4/23/2020',
#        'Racial': 'missing',
#        'Category / Type': 'Citizen',
#        'Location Of Occurrence': 'missing',
#        'Disposition': 'missing',
#        'Completed': '10/20/2020',
#        'Recorded On Camera': 'Body Camera'}]},
#     {'type': 'kv',
#      'content': [{'Complainant': 'missing'},
#       {'DOB': 'missing'},
#       {'Gender': 'MALE'},
#       {'Address': 'Street, Champaign IL 61820'},
#       {'H Phone': 'missing'}]},
#     {'type': 'table',
#      'content': [{'Type Of Complaint': 'R-1A1 CONDUCT GENERALLY',
#        'Description': 'Poor Judgement',
#        'Complaint Disposition': 'EXONERATED'},
#       {'Type Of Complaint': 'R-1A2 CONDUCT GENERALLY',
#        'Description': 'Poor Judgement',
#        'Complaint Disposition': 'EXONERATED'}]},
#     {'type': 'table',
#      'content': [{'Name': 'Griffet, David I.',
#        'ID No.': '914',
#        'Rank': 'SERGEANT',
#        'Division': 'Operations Supp',
#        'Officer Disposition': 'Pending',
#        'Action Taken': 'Pending',
#        'Body Cam': 'No'},
#       {'Name': 'ADMINISTRATIVE Database',
#        'ID No.': '26 AM',
#        'Rank': 'missing',
#        'Division': 'missing',
#        'Officer Disposition': 'missing',
#        'Action Taken': 'missing',
#        'Body Cam': 'Page 71 of 74'}]}]},
#   {'id': 259,
#    'content': [{'type': 'table',
#      'content': [{'Date': 'missing',
#        'Number': 'missing',
#        'Investigator': 'missing',
#        'Date Assigned': '5/24/2020',
#        'Racial': 'missing',
#        'Category / Type': 'missing',
#        'Location Of Occurrence': 'missing',
#        'Disposition': 'missing',
#        'Completed': 'missing',
#        'Recorded On Camera': 'Body Camera'}]},
#     {'type': 'kv',
#      'content': [{'Complainant': 'Anthony Cobb'},
#       {'DOB': 'missing'},
#       {'Gender': 'missing'},
#       {'Address': '82 E University Avenue, Champaign IL 61820'},
#       {'H Phone': 'missing'}]},
#     {'type': 'table',
#      'content': [{'Type Of Complaint': 'R-5A3 OPERATIONS',
#        'Description': 'FAILED TO TAKE APPROPRIATE ACTIO',
#        'Complaint Disposition': 'Pending'}]},
#     {'type': 'table',
#      'content': [{'Name': 'Briceno-Garcia, Isidro',
#        'ID No.': '789',
#        'Rank': 'RECRUIT OFFIC',
#        'Division': 'PATROL',
#        'Officer Disposition': 'Pending',
#        'Action Taken': 'Pending',
#        'Body Cam': 'No'}]}]},
#   {'id': 260,
#    'content': [{'type': 'table',
#      'content': [{'Date': 'missing',
#        'Number': 'missing',
#        'Investigator': 'missing',
#        'Date Assigned': '6/4/2020',
#        'Racial': 'missing',
#        'Category / Type': 'Citizen',
#        'Location Of Occurrence': 'missing',
#        'Disposition': 'missing',
#        'Completed': '10/5/2020',
#        'Recorded On Camera': 'Body Camera'}]},
#     {'type': 'kv',
#      'content': [{'Complainant': 'missing'},
#       {'DOB': 'missing'},
#       {'Gender': 'FEMAL'},
#       {'Address': ', Danville IL 61832'},
#       {'H Phone': 'missing'}]},
#     {'type': 'table',
#      'content': [{'Type Of Complaint': 'R-3B COURTESY',
#        'Description': 'Discourteous Conduct',
#        'Complaint Disposition': 'UNFOUNDED'},
#       {'Type Of Complaint': 'R-5A3 OPERATIONS',
#        'Description': 'Discourteous Conduct; Wrong Action',
#        'Complaint Disposition': 'EXONERATED'},
#       {'Type Of Complaint': 'R-5D Use of physical force',
#        'Description': 'Excessive Force',
#        'Complaint Disposition': 'EXONERATED'}]},
#     {'type': 'table',
#      'content': [{'Name': 'Lack, Aaron V.',
#        'ID No.': '920',
#        'Rank': 'SERGEANT',
#        'Division': 'Field Operations',
#        'Officer Disposition': 'EXONERATED',
#        'Action Taken': 'Pending',
#        'Body Cam': 'No'}]}]},
#   {'id': 261,
#    'content': [{'type': 'table',
#      'content': [{'Date': 'missing',
#        'Number': 'missing',
#        'Investigator': 'missing',
#        'Date Assigned': '7/13/2020',
#        'Racial': 'missing',
#        'Category / Type': 'Citizen',
#        'Location Of Occurrence': 'missing',
#        'Disposition': 'missing',
#        'Completed': 'missing',
#        'Recorded On Camera': 'Body Camera'}]},
#     {'type': 'kv',
#      'content': [{'Complainant': 'missing'},
#       {'DOB': 'missing'},
#       {'Gender': 'MALE'},
#       {'Address': '2, Champaign IL 61821'},
#       {'H Phone': 'missing'}]},
#     {'type': 'table',
#      'content': [{'Type Of Complaint': 'R-1A2 POOR JUDGEMENT',
#        'Description': 'FAILED TO TAKE APPROPRIATE ACTIO',
#        'Complaint Disposition': 'Pending'}]},
#     {'type': 'table',
#      'content': [{'Name': 'McElwee, Molly J',
#        'ID No.': '784',
#        'Rank': 'RECRUIT OFFIC',
#        'Division': 'PATROL',
#        'Officer Disposition': 'Pending',
#        'Action Taken': 'Pending',
#        'Body Cam': 'No'},
#       {'Name': 'Nickell, John P.',
#        'ID No.': '7121',
#        'Rank': 'OFFICER',
#        'Division': 'PATROL',
#        'Officer Disposition': 'Pending',
#        'Action Taken': 'Pending',
#        'Body Cam': 'No'},
#       {'Name': 'Pesavento, Kevin',
#        'ID No.': '7795',
#        'Rank': 'OFFICER',
#        'Division': 'PATROL',
#        'Officer Disposition': 'Pending',
#        'Action Taken': 'Pending',
#        'Body Cam': 'No'},
#       {'Name': 'ADMINISTRATIVE Database',
#        'ID No.': '26 AM',
#        'Rank': 'missing',
#        'Division': 'missing',
#        'Officer Disposition': 'missing',
#        'Action Taken': 'missing',
#        'Body Cam': 'Page 72 of 74'}]}]},
#   {'id': 262,
#    'content': [{'type': 'table',
#      'content': [{'Date': '7/14/2020',
#        'Number': '20-08',
#        'Investigator': 'NEWELL, BEN',
#        'Date Assigned': 'missing',
#        'Racial': 'No',
#        'Category / Type': 'Formal',
#        'Location Of Occurrence': '82 E UNIVERSITY AVE',
#        'Disposition': 'Pending',
#        'Completed': 'missing',
#        'Recorded On Camera': 'Yes'},
#       {'Date': 'missing',
#        'Number': 'missing',
#        'Investigator': 'missing',
#        'Date Assigned': '7/16/2020',
#        'Racial': 'missing',
#        'Category / Type': 'Citizen',
#        'Location Of Occurrence': 'missing',
#        'Disposition': 'missing',
#        'Completed': 'missing',
#        'Recorded On Camera': 'Body Camera'}]},
#     {'type': 'kv',
#      'content': [{'Complainant': 'missing'},
#       {'DOB': 'missing'},
#       {'Gender': 'FEMAL'},
#       {'Address': 'Street, Philo IL 61864'},
#       {'H Phone': 'missing'}]},
#     {'type': 'table',
#      'content': [{'Type Of Complaint': 'R-3B COURTESY',
#        'Description': 'Discourteous Conduct',
#        'Complaint Disposition': 'Pending'},
#       {'Type Of Complaint': 'R-5A3 OPERATIONS',
#        'Description': 'FAILED TO TAKE APPROPRIATE ACTIO',
#        'Complaint Disposition': 'Pending'}]},
#     {'type': 'table',
#      'content': [{'Name': 'McDonald, Philip',
#        'ID No.': '781',
#        'Rank': 'Senior',
#        'Division': 'Field Operations',
#        'Officer Disposition': 'Pending',
#        'Action Taken': 'Pending',
#        'Body Cam': 'No'}]}]},
#   {'id': 263,
#    'content': [{'type': 'table',
#      'content': [{'Date': 'missing',
#        'Number': 'missing',
#        'Investigator': 'missing',
#        'Date Assigned': 'missing',
#        'Racial': 'missing',
#        'Category / Type': 'Internal',
#        'Location Of Occurrence': 'missing',
#        'Disposition': 'missing',
#        'Completed': 'missing',
#        'Recorded On Camera': 'N/A'}]},
#     {'type': 'kv',
#      'content': [{'Complainant': 'Anthony Cobb'},
#       {'DOB': 'missing'},
#       {'Gender': 'missing'},
#       {'Address': '82 East University Avenue, Champaign IL 61820'},
#       {'H Phone': 'missing'}]},
#     {'type': 'table',
#      'content': [{'Type Of Complaint': 'R-1A1 CONDUCT GENERALLY',
#        'Description': 'missing',
#        'Complaint Disposition': 'Pending'}]},
#     {'type': 'table',
#      'content': [{'Name': 'Griffet, Danielle J.',
#        'ID No.': '7755',
#        'Rank': 'OFFICER',
#        'Division': 'PATROL',
#        'Officer Disposition': 'Pending',
#        'Action Taken': 'Pending',
#        'Body Cam': 'No'}]}]},
#   {'id': 264,
#    'content': [{'type': 'table',
#      'content': [{'Date': 'missing',
#        'Number': 'missing',
#        'Investigator': 'missing',
#        'Date Assigned': '11/3/2020',
#        'Racial': 'missing',
#        'Category / Type': 'Citizen',
#        'Location Of Occurrence': 'missing',
#        'Disposition': 'missing',
#        'Completed': 'missing',
#        'Recorded On Camera': 'N/A'}]},
#     {'type': 'kv',
#      'content': [{'Complainant': 'missing'},
#       {'DOB': '0'},
#       {'Gender': 'FEMAL'},
#       {'Address': '622 West Hill Street, Champaign IL 61820'},
#       {'H Phone': 'missing'}]},
#     {'type': 'table',
#      'content': [{'Name': 'Ward, Daniel W.',
#        'ID No.': '767',
#        'Rank': 'OFFICER',
#        'Division': 'Field Operations',
#        'Officer Disposition': 'Pending',
#        'Action Taken': 'Pending',
#        'Body Cam': 'No'}]}]},
#   {'id': 265,
#    'content': [{'type': 'table',
#      'content': [{'Date': '9/7/2020',
#        'Number': '20-10',
#        'Investigator': 'LIBE, JOHN',
#        'Date Assigned': 'missing',
#        'Racial': 'No',
#        'Category / Type': 'Formal',
#        'Location Of Occurrence': 'LYNN STREET AT CHARLES STREET',
#        'Disposition': 'Pending',
#        'Completed': 'missing',
#        'Recorded On Camera': 'Yes'},
#       {'Date': 'missing',
#        'Number': 'missing',
#        'Investigator': 'missing',
#        'Date Assigned': '9/14/2020',
#        'Racial': 'missing',
#        'Category / Type': 'Citizen',
#        'Location Of Occurrence': 'missing',
#        'Disposition': 'missing',
#        'Completed': 'missing',
#        'Recorded On Camera': 'Body Camera'}]},
#     {'type': 'kv',
#      'content': [{'Complainant': 'missing'},
#       {'DOB': 'missing'},
#       {'Gender': 'MALE'},
#       {'Address': 'Street, Champaign IL 61820'},
#       {'H Phone': 'missing'}]},
#     {'type': 'table',
#      'content': [{'Type Of Complaint': 'R-1A2 POOR JUDGEMENT',
#        'Description': 'Discourteous Conduct; Wrong Action',
#        'Complaint Disposition': 'Pending'},
#       {'Type Of Complaint': 'R-1A2 POOR JUDGEMENT',
#        'Description': 'FAILED TO TAKE APPROPRIATE ACTIO',
#        'Complaint Disposition': 'Pending'},
#       {'Type Of Complaint': 'R-3B COURTESY',
#        'Description': 'Discourteous Conduct; Wrong Action',
#        'Complaint Disposition': 'Pending'},
#       {'Type Of Complaint': 'R-5A3 OPERATIONS',
#        'Description': 'FAILURE TO DOCUMENT EVIDENCE',
#        'Complaint Disposition': 'Pending'},
#       {'Type Of Complaint': 'R-5A3 OPERATIONS',
#        'Description': 'Wrong Action by Employee',
#        'Complaint Disposition': 'Pending'}]},
#     {'type': 'table',
#      'content': [{'Name': 'Broadnax, Jherion',
#        'ID No.': '7756',
#        'Rank': 'RECRUIT OFFIC',
#        'Division': 'PATROL',
#        'Officer Disposition': 'Pending',
#        'Action Taken': 'Pending',
#        'Body Cam': 'No'},
#       {'Name': 'ADMINISTRATIVE Database',
#        'ID No.': '26 AM',
#        'Rank': 'missing',
#        'Division': 'missing',
#        'Officer Disposition': 'missing',
#        'Action Taken': 'missing',
#        'Body Cam': 'Page 73 of 74'}]}]},
#   {'id': 266,
#    'content': [{'type': 'table',
#      'content': [{'Date': 'missing',
#        'Number': 'missing',
#        'Investigator': 'missing',
#        'Date Assigned': 'missing',
#        'Racial': 'missing',
#        'Category / Type': 'Internal',
#        'Location Of Occurrence': 'missing',
#        'Disposition': 'missing',
#        'Completed': 'missing',
#        'Recorded On Camera': 'N/A'}]},
#     {'type': 'kv',
#      'content': [{'Complainant': 'Anthony Cobb'},
#       {'DOB': 'missing'},
#       {'Gender': 'missing'},
#       {'Address': '82 E University Avenue, Champaign IL 61820'},
#       {'H Phone': '(217) 351-4545'}]},
#     {'type': 'table',
#      'content': [{'Type Of Complaint': 'R-1A1 CONDUCT GENERALLY',
#        'Description': 'missing',
#        'Complaint Disposition': 'Pending'},
#       {'Type Of Complaint': 'R-3A.2 INSUBORDINATION',
#        'Description': 'missing',
#        'Complaint Disposition': 'Pending'},
#       {'Type Of Complaint': 'R-3B.1 Courtesy',
#        'Description': 'missing',
#        'Complaint Disposition': 'Pending'},
#       {'Type Of Complaint': 'R-4A USE OF PROPERTY GENERALLY',
#        'Description': 'missing',
#        'Complaint Disposition': 'Pending'}]},
#     {'type': 'table',
#      'content': [{'Name': 'Henry, Marshall',
#        'ID No.': '7111',
#        'Rank': 'OFFICER',
#        'Division': 'INVESTIGATION',
#        'Officer Disposition': 'Pending',
#        'Action Taken': 'Pending',
#        'Body Cam': 'No'}]}]},
#   {'id': 267,
#    'content': [{'type': 'table',
#      'content': [{'Date': '9/27/2020',
#        'Number': '20-11',
#        'Investigator': 'NEWELL, BEN',
#        'Date Assigned': 'missing',
#        'Racial': 'No',
#        'Category / Type': 'Formal',
#        'Location Of Occurrence': 'Neil St at Fox Dr',
#        'Disposition': 'Pending',
#        'Completed': 'missing',
#        'Recorded On Camera': 'Yes'},
#       {'Date': 'missing',
#        'Number': 'missing',
#        'Investigator': 'missing',
#        'Date Assigned': '10/16/2020',
#        'Racial': 'missing',
#        'Category / Type': 'Citizen',
#        'Location Of Occurrence': 'missing',
#        'Disposition': 'missing',
#        'Completed': 'missing',
#        'Recorded On Camera': 'Body Camera'}]},
#     {'type': 'kv',
#      'content': [{'Complainant': 'missing'},
#       {'DOB': 'missing'},
#       {'Gender': 'FEMAL'},
#       {'Address': ', Urbana IL 61801'},
#       {'H Phone': 'missing'}]},
#     {'type': 'table',
#      'content': [{'Type Of Complaint': 'R-2A COMMUNICATION',
#        'Description': 'DOCUMENTED FALSE INFORMATION',
#        'Complaint Disposition': 'Pending'},
#       {'Type Of Complaint': 'R-2A.1 POOR REPORT',
#        'Description': 'INCORRECTLY DOCUMENTED INFORM',
#        'Complaint Disposition': 'Pending'},
#       {'Type Of Complaint': 'R-2A.1 POOR REPORT',
#        'Description': 'INCORRECTLY DOCUMENTED INFORM',
#        'Complaint Disposition': 'Pending'}]},
#     {'type': 'table',
#      'content': [{'Name': 'Reilly, Kyle P.',
#        'ID No.': '721',
#        'Rank': 'RECRUIT OFFIC',
#        'Division': 'PATROL',
#        'Officer Disposition': 'Pending',
#        'Action Taken': 'Pending',
#        'Body Cam': 'No'}]}]},
#   {'id': 268,
#    'content': [{'type': 'table',
#      'content': [{'Date': 'missing',
#        'Number': 'missing',
#        'Investigator': 'missing',
#        'Date Assigned': '10/16/2020',
#        'Racial': 'missing',
#        'Category / Type': 'Citizen',
#        'Location Of Occurrence': 'missing',
#        'Disposition': 'missing',
#        'Completed': 'missing',
#        'Recorded On Camera': 'Body Camera'}]},
#     {'type': 'kv',
#      'content': [{'Complainant': 'missing'},
#       {'DOB': 'missing'},
#       {'Gender': 'FEMAL'},
#       {'Address': 'Drive, Champaign IL 61821'},
#       {'H Phone': 'missing'}]},
#     {'type': 'table',
#      'content': [{'Type Of Complaint': 'R-1A1 CONDUCT GENERALLY',
#        'Description': 'FAILED TO TAKE APPROPRIATE ACTIO',
#        'Complaint Disposition': 'Pending'},
#       {'Type Of Complaint': 'R-3B.1 Courtesy',
#        'Description': 'Discourteous Conduct',
#        'Complaint Disposition': 'Pending'}]},
#     {'type': 'table',
#      'content': [{'Name': 'Kaldahl, Erik',
#        'ID No.': '733',
#        'Rank': 'OFFICER',
#        'Division': 'PATROL',
#        'Officer Disposition': 'Pending',
#        'Action Taken': 'Pending',
#        'Body Cam': 'No'}]}]}]}
